# %% [markdown]
# # **Dataset & Description**
#
#
#
# [![image.png](attachment:image.png)](http://)
#
#
# The data consists of 48x48 pixel grayscale images of faces. The faces have been automatically registered so that the face is more or less centred and occupies about the same amount of space in each image.
#
# The task is to categorize each face based on the emotion shown in the facial expression into one of seven categories (0=Angry, 1=Disgust, 2=Fear, 3=Happy, 4=Sad, 5=Surprise, 6=Neutral). The training set consists of 28,709 examples and the public test set consists of 3,589 examples.
#
#
#
#
#
#
#
#
# [Dataset link ](https://www.kaggle.com/msambare/fer2013)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils, datasets

# %%
class EyeDiseaseClassicationImageDataset(torch.utils.data.Dataset):
    def __init__(self, root_dir, transform=None):
        self.dataset = datasets.ImageFolder(root=root_dir, transform=transform)
        self.classes = self.dataset.classes

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        return self.dataset[idx]

# %%
root_directory = '/kaggle/input/'

data_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize(size = (224, 224)),
    transforms.RandomRotation(degrees=5),
    transforms.RandomHorizontalFlip(p=0.5),
])

dataset = EyeDiseaseClassicationImageDataset(root_dir='/kaggle/input/dataset', transform=data_transform)

# %%
DEVICE = 'cuda:0'

# %%
# split data into train, val and test datasets
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [int(len(dataset)*0.9), len(dataset) - int(len(dataset)*0.9)])
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [int(len(train_dataset)*0.8), len(train_dataset) - int(len(train_dataset)*0.8)])

# %%
print(f"Train dataset size: {len(train_dataset)}")
print(f"Test dataset size: {len(test_dataset)}")
print(f"Val dataset size: {len(val_dataset)}")
# Out:
# Train dataset size: 3036
# Test dataset size: 422
# Val dataset size: 759

# %%
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size)
sample_img, sample_lbl = next(iter(train_loader))
print(f"Image batch shape: {sample_img.size()}")
print(f"Label batch shape: {sample_lbl.size()}")
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Image batch shape: torch.Size([64, 3, 224, 224])
# Label batch shape: torch.Size([64])

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from skimage import io
import cv2
img = train_dataset[3][0]
imgplot = plt.imshow(img.permute(1,2,0))
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %% [markdown]
# # Model

# %%
import torchvision.models as models
from torchvision.models import resnet50, ResNet50_Weights, resnet18, ResNet18_Weights, vgg19, VGG19_Weights
import torch.nn as nn
import tqdm

# %%
model = models.resnet50(weights = ResNet50_Weights.IMAGENET1K_V1)

for param in model.parameters():
    param.requires_grad = False
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 218MB/s]

# %%
# modify the classifier layer
model.fc = nn.Sequential(nn.Linear(2048, 1024), nn.ReLU(), nn.Linear(1024, 1024), nn.ReLU(), nn.Linear(1024,4))

# %%
model = model.to(DEVICE)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=1024, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=1024, out_features=4, bias=True)
#   )
# )

# %%
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []
def evaluate(model, data_loader, criterion):
    """Evaluate the model on the given dataset."""
    # Set the model to evaluation mode.
    model.eval()
    correct = 0
    val_loss = 0
    count = 0
    # The `torch.no_grad()` context will turn off gradients for efficiency.
    with torch.no_grad():
        for images, labels in (data_loader):
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            output = model(images)
            pred = output.argmax(dim=1)
            loss = criterion(output, labels)
            correct += (pred == labels).sum().item()
            val_loss += loss.item()
            
            count += 1
    val_losses.append(val_loss/count)
    return correct / len(data_loader.dataset), val_loss/count


def train(model, n_epoch, optimizer, scheduler):
    """Train the model on the given dataset."""
    loss_ref = float('inf')
    for epoch in range(n_epoch):
        # Set the model to training mode.
        correct = 0
        model.train()
        for step, (images, labels) in enumerate(train_loader):
            # 0. Prepare the data. Move the data to the device (CPU/GPU).
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            # 1. Clear previous gradients.
            optimizer.zero_grad()
            # 2. Forward pass. Calculate the output of the model.
            output = model(images)
            pred = output.argmax(dim=1)
            correct += (pred==labels).sum().item()
            # 3. Calculate the loss.
            loss = criterion(output, labels)
            # 4. Calculate the gradients. PyTorch does this for us!
            loss.backward()
            # 5. Update the model parameters.
            optimizer.step()
            if step % 5 == 0:
                print(f"Epoch {epoch}, Step {step}, Loss {loss.item():.4f}")
        
        train_acc = correct/len(train_loader.dataset)
        train_losses.append(loss.cpu().detach().numpy())
        acc, val_loss = evaluate(model, valid_loader, criterion)
        scheduler.step(val_loss)
        train_accuracies.append(train_acc)
        val_accuracies.append(acc)
        print(f"Epoch {epoch}, Valid Accuracy {acc * 100:.2f}%, Train Accuracy {train_acc * 100:.2f}%, Val loss {val_loss}")  # Train the model for 10 epochs.
        
        if val_loss < loss_ref:
            patience = 5
            loss_ref = val_loss
        else:
            if patience == 0:
                print(f"[Early Stopping] Epoch {epoch}, Valid Accuracy {acc * 100:.2f}%, Valid Loss {val_loss:.4f}")
                return
            print(f"[INFO] Patience {patience} remaining")
            patience-=1

# %%
lr = 1e-3
gamma = 0.9
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, verbose=True)

n_epoch = 100
train(model, n_epoch, optimizer, scheduler)
# Out:
# Epoch 0, Step 0, Loss 1.3875
# Epoch 0, Step 5, Loss 1.2323
# Epoch 0, Step 10, Loss 1.2033
# Epoch 0, Step 15, Loss 0.7162
# Epoch 0, Step 20, Loss 0.7971
# Epoch 0, Step 25, Loss 0.6182
# Epoch 0, Step 30, Loss 0.4559
# Epoch 0, Step 35, Loss 0.5668
# Epoch 0, Step 40, Loss 0.7273
# Epoch 0, Step 45, Loss 0.6041
# Epoch 0, Valid Accuracy 78.13%, Train Accuracy 63.37%, Val loss 0.6052116304636002
# Epoch 1, Step 0, Loss 0.4532
# Epoch 1, Step 5, Loss 0.4894
# Epoch 1, Step 10, Loss 0.4506
# Epoch 1, Step 15, Loss 0.3914
# Epoch 1, Step 20, Loss 0.5622
# Epoch 1, Step 25, Loss 0.4914
# Epoch 1, Step 30, Loss 0.4839
# Epoch 1, Step 35, Loss 0.4618
# Epoch 1, Step 40, Loss 0.6478
# Epoch 1, Step 45, Loss 0.3805
# Epoch 1, Valid Accuracy 80.24%, Train Accuracy 80.17%, Val loss 0.5018978690107664
# Epoch 2, Step 0, Loss 0.4125
# Epoch 2, Step 5, Loss 0.3279
# Epoch 2, Step 10, Loss 0.5788
# Epoch 2, Step 15, Loss 0.3914
# Epoch 2, Step 20, Loss 0.4431
# Epoch 2, Step 25, Loss 0.6561
# Epoch 2, Step 30, Loss 0.7218
# Epoch 2, Step 35, Loss 0.4260
# Epoch 2, Step 40, Loss 0.4196
# Epoch 2, Step 45, Loss 0.3177
# Epoch 2, Valid Accuracy 77.60%, Train Accuracy 82.05%, Val loss 0.6111784453193346
# [INFO] Patience 5 remaining
# Epoch 3, Step 0, Loss 0.4409
# Epoch 3, Step 5, Loss 0.4818
# Epoch 3, Step 10, Loss 0.3718
# Epoch 3, Step 15, Loss 0.4558
# Epoch 3, Step 20, Loss 0.5698
# Epoch 3, Step 25, Loss 0.3702
# Epoch 3, Step 30, Loss 0.3695
# Epoch 3, Step 35, Loss 0.3162
# Epoch 3, Step 40, Loss 0.5693
# Epoch 3, Step 45, Loss 0.3711
# Epoch 3, Valid Accuracy 75.63%, Train Accuracy 84.09%, Val loss 0.6213328142960867
# [INFO] Patience 4 remaining
# Epoch 4, Step 0, Loss 0.6592
# Epoch 4, Step 5, Loss 0.3967
# Epoch 4, Step 10, Loss 0.5464
# Epoch 4, Step 15, Loss 0.3605
# Epoch 4, Step 20, Loss 0.3454
# Epoch 4, Step 25, Loss 0.2210
# Epoch 4, Step 30, Loss 0.3721
# Epoch 4, Step 35, Loss 0.5871
# Epoch 4, Step 40, Loss 0.2785
# Epoch 4, Step 45, Loss 0.3371
# Epoch 4, Valid Accuracy 84.19%, Train Accuracy 84.95%, Val loss 0.436854047079881
# Epoch 5, Step 0, Loss 0.1700
# Epoch 5, Step 5, Loss 0.3520
# Epoch 5, Step 10, Loss 0.3450
# Epoch 5, Step 15, Loss 0.3625
# Epoch 5, Step 20, Loss 0.2653
# Epoch 5, Step 25, Loss 0.2782
# Epoch 5, Step 30, Loss 0.6458
# Epoch 5, Step 35, Loss 0.5058
# Epoch 5, Step 40, Loss 0.4792
# Epoch 5, Step 45, Loss 0.5888
# Epoch 5, Valid Accuracy 74.97%, Train Accuracy 84.42%, Val loss 0.6743036632736524
# [INFO] Patience 5 remaining
# Epoch 6, Step 0, Loss 0.7521
# Epoch 6, Step 5, Loss 0.4313
# Epoch 6, Step 10, Loss 0.4383
# Epoch 6, Step 15, Loss 0.3911
# Epoch 6, Step 20, Loss 0.3372
# Epoch 6, Step 25, Loss 0.4509
# Epoch 6, Step 30, Loss 0.3788
# Epoch 6, Step 35, Loss 0.3230
# Epoch 6, Step 40, Loss 0.3067
# Epoch 6, Step 45, Loss 0.2044
# Epoch 6, Valid Accuracy 84.85%, Train Accuracy 84.45%, Val loss 0.3887535631656647
# Epoch 7, Step 0, Loss 0.2861
# Epoch 7, Step 5, Loss 0.2932
# Epoch 7, Step 10, Loss 0.3308
# Epoch 7, Step 15, Loss 0.3500
# Epoch 7, Step 20, Loss 0.2243
# Epoch 7, Step 25, Loss 0.3127
# Epoch 7, Step 30, Loss 0.3743
# Epoch 7, Step 35, Loss 0.3362
# Epoch 7, Step 40, Loss 0.4237
# Epoch 7, Step 45, Loss 0.5104
# Epoch 7, Valid Accuracy 82.61%, Train Accuracy 86.92%, Val loss 0.4533606717983882
# [INFO] Patience 5 remaining
# Epoch 8, Step 0, Loss 0.3097
# Epoch 8, Step 5, Loss 0.3002
# Epoch 8, Step 10, Loss 0.3085
# Epoch 8, Step 15, Loss 0.2874
# Epoch 8, Step 20, Loss 0.2752
# Epoch 8, Step 25, Loss 0.1736
# Epoch 8, Step 30, Loss 0.3665
# Epoch 8, Step 35, Loss 0.3595
# Epoch 8, Step 40, Loss 0.2733
# Epoch 8, Step 45, Loss 0.3685
# Epoch 8, Valid Accuracy 83.40%, Train Accuracy 87.35%, Val loss 0.40809224049250287
# [INFO] Patience 4 remaining
# Epoch 9, Step 0, Loss 0.3282
# Epoch 9, Step 5, Loss 0.4087
# Epoch 9, Step 10, Loss 0.3585
# Epoch 9, Step 15, Loss 0.3494
# Epoch 9, Step 20, Loss 0.4106
# Epoch 9, Step 25, Loss 0.3807
# Epoch 9, Step 30, Loss 0.3282
# Epoch 9, Step 35, Loss 0.3556
# Epoch 9, Step 40, Loss 0.3102
# Epoch 9, Step 45, Loss 0.3417
# Epoch 9, Valid Accuracy 83.00%, Train Accuracy 87.06%, Val loss 0.4469073911507924
# [INFO] Patience 3 remaining
# Epoch 10, Step 0, Loss 0.3500
# Epoch 10, Step 5, Loss 0.2723
# Epoch 10, Step 10, Loss 0.4456
# Epoch 10, Step 15, Loss 0.3173
# Epoch 10, Step 20, Loss 0.1801
# Epoch 10, Step 25, Loss 0.2189
# Epoch 10, Step 30, Loss 0.3385
# Epoch 10, Step 35, Loss 0.3197
# Epoch 10, Step 40, Loss 0.2126
# Epoch 10, Step 45, Loss 0.2325
# Epoch 00011: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 10, Valid Accuracy 83.00%, Train Accuracy 85.84%, Val loss 0.4442366659641266
# [INFO] Patience 2 remaining
# Epoch 11, Step 0, Loss 0.4432
# Epoch 11, Step 5, Loss 0.2050
# Epoch 11, Step 10, Loss 0.4322
# Epoch 11, Step 15, Loss 0.3691
# Epoch 11, Step 20, Loss 0.2575
# Epoch 11, Step 25, Loss 0.3383
# Epoch 11, Step 30, Loss 0.3470
# Epoch 11, Step 35, Loss 0.1804
# Epoch 11, Step 40, Loss 0.2783
# Epoch 11, Step 45, Loss 0.2869
# Epoch 11, Valid Accuracy 85.38%, Train Accuracy 89.59%, Val loss 0.38215778892238933
# Epoch 12, Step 0, Loss 0.2006
# Epoch 12, Step 5, Loss 0.2992
# Epoch 12, Step 10, Loss 0.2458
# Epoch 12, Step 15, Loss 0.3166
# Epoch 12, Step 20, Loss 0.1309
# Epoch 12, Step 25, Loss 0.3132
# Epoch 12, Step 30, Loss 0.3116
# Epoch 12, Step 35, Loss 0.1807
# Epoch 12, Step 40, Loss 0.2624
# Epoch 12, Step 45, Loss 0.3117
# Epoch 12, Valid Accuracy 84.58%, Train Accuracy 90.25%, Val loss 0.3876880829532941
# [INFO] Patience 5 remaining
# Epoch 13, Step 0, Loss 0.1838
# Epoch 13, Step 5, Loss 0.3093
# Epoch 13, Step 10, Loss 0.1925
# Epoch 13, Step 15, Loss 0.3589
# Epoch 13, Step 20, Loss 0.2608
# Epoch 13, Step 25, Loss 0.2300
# Epoch 13, Step 30, Loss 0.1794
# Epoch 13, Step 35, Loss 0.1957
# Epoch 13, Step 40, Loss 0.2699
# Epoch 13, Step 45, Loss 0.2867
# Epoch 13, Valid Accuracy 86.17%, Train Accuracy 90.05%, Val loss 0.3641483634710312
# Epoch 14, Step 0, Loss 0.2325
# Epoch 14, Step 5, Loss 0.2598
# Epoch 14, Step 10, Loss 0.3396
# Epoch 14, Step 15, Loss 0.2154
# Epoch 14, Step 20, Loss 0.1208
# Epoch 14, Step 25, Loss 0.0696
# Epoch 14, Step 30, Loss 0.1691
# Epoch 14, Step 35, Loss 0.2630
# Epoch 14, Step 40, Loss 0.1726
# Epoch 14, Step 45, Loss 0.2051
# Epoch 14, Valid Accuracy 83.66%, Train Accuracy 90.94%, Val loss 0.410143847266833
# [INFO] Patience 5 remaining
# Epoch 15, Step 0, Loss 0.3346
# Epoch 15, Step 5, Loss 0.2089
# Epoch 15, Step 10, Loss 0.1216
# Epoch 15, Step 15, Loss 0.2146
# Epoch 15, Step 20, Loss 0.1942
# Epoch 15, Step 25, Loss 0.3568
# Epoch 15, Step 30, Loss 0.1912
# Epoch 15, Step 35, Loss 0.2497
# Epoch 15, Step 40, Loss 0.3397
# Epoch 15, Step 45, Loss 0.1647
# Epoch 15, Valid Accuracy 84.72%, Train Accuracy 91.07%, Val loss 0.39471903070807457
# [INFO] Patience 4 remaining
# Epoch 16, Step 0, Loss 0.1517
# Epoch 16, Step 5, Loss 0.2105
# Epoch 16, Step 10, Loss 0.2249
# Epoch 16, Step 15, Loss 0.3673
# Epoch 16, Step 20, Loss 0.2937
# Epoch 16, Step 25, Loss 0.1960
# Epoch 16, Step 30, Loss 0.2465
# Epoch 16, Step 35, Loss 0.1581
# Epoch 16, Step 40, Loss 0.2760
# Epoch 16, Step 45, Loss 0.1957
# Epoch 16, Valid Accuracy 85.24%, Train Accuracy 90.91%, Val loss 0.38154107208053273
# [INFO] Patience 3 remaining
# Epoch 17, Step 0, Loss 0.1225
# Epoch 17, Step 5, Loss 0.2269
# Epoch 17, Step 10, Loss 0.1781
# Epoch 17, Step 15, Loss 0.1804
# Epoch 17, Step 20, Loss 0.3013
# Epoch 17, Step 25, Loss 0.2845
# Epoch 17, Step 30, Loss 0.2560
# Epoch 17, Step 35, Loss 0.1749
# Epoch 17, Step 40, Loss 0.1840
# Epoch 17, Step 45, Loss 0.3349
# Epoch 00018: reducing learning rate of group 0 to 1.0000e-05.
# Epoch 17, Valid Accuracy 84.85%, Train Accuracy 90.97%, Val loss 0.3844291642308235
# [INFO] Patience 2 remaining
# Epoch 18, Step 0, Loss 0.2073
# Epoch 18, Step 5, Loss 0.2801
# Epoch 18, Step 10, Loss 0.3017
# Epoch 18, Step 15, Loss 0.3501
# Epoch 18, Step 20, Loss 0.1714
# Epoch 18, Step 25, Loss 0.2184
# Epoch 18, Step 30, Loss 0.1521
# Epoch 18, Step 35, Loss 0.1394
# Epoch 18, Step 40, Loss 0.2303
# Epoch 18, Step 45, Loss 0.2680
# Epoch 18, Valid Accuracy 85.90%, Train Accuracy 91.14%, Val loss 0.3842117463548978
# [INFO] Patience 1 remaining
# Epoch 19, Step 0, Loss 0.1632
# Epoch 19, Step 5, Loss 0.2868
# Epoch 19, Step 10, Loss 0.2855
# Epoch 19, Step 15, Loss 0.2063
# Epoch 19, Step 20, Loss 0.1631
# Epoch 19, Step 25, Loss 0.2145
# Epoch 19, Step 30, Loss 0.3294
# Epoch 19, Step 35, Loss 0.1654
# Epoch 19, Step 40, Loss 0.2004
# Epoch 19, Step 45, Loss 0.2917
# Epoch 19, Valid Accuracy 84.58%, Train Accuracy 90.94%, Val loss 0.3740274781982104
# [Early Stopping] Epoch 19, Valid Accuracy 84.58%, Valid Loss 0.3740

# %%
def test(model, data_loader):
    """Evaluate the model on the given dataset."""
    # Set the model to evaluation mode.
    model.eval()
    correct = 0
    
    all_labels = []
    all_preds = []

    # The `torch.no_grad()` context will turn off gradients for efficiency.
    with torch.no_grad():
        for images, labels in (data_loader):
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            output = model(images)
            pred = output.argmax(dim=1)
            correct += (pred == labels).sum().item()
            all_labels.extend([x.cpu().detach() for x in labels])
            all_preds.extend([x.cpu().detach() for x in pred])

    return correct / len(data_loader.dataset), all_labels, all_preds

# %%
test_accuracy, labels, preds = test(model, test_loader)

# %%
test_accuracy
# Out:
# 0.8838862559241706

# %%
torch.save(model, '/kaggle/working/resnet_best.pth')

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(train_losses) + 1)

# Plotting
plt.figure(figsize=(8, 6))
plt.ylim([-1,2])
plt.plot(epochs, train_losses, 'b', label='Training Loss')
plt.plot(epochs, val_losses, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(train_accuracies) + 1)

# Plotting
plt.figure(figsize=(8, 6))
plt.ylim([0.5,1.2])
plt.plot(epochs, train_accuracies, 'b', label='Training Accuracy')
plt.plot(epochs, val_accuracies, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
# !pip install torcheval
# Out:
# Collecting torcheval
#   Obtaining dependency information for torcheval from https://files.pythonhosted.org/packages/e4/de/e7abc784b00de9d05999657d29187f1f7a3406ed10ecaf164de06482608f/torcheval-0.0.7-py3-none-any.whl.metadata
#   Downloading torcheval-0.0.7-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torcheval) (4.5.0)
# Downloading torcheval-0.0.7-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 9.0 MB/s eta 0:00:00
# Installing collected packages: torcheval
# Successfully installed torcheval-0.0.7

# %%
from torcheval.metrics.functional import multiclass_f1_score
multiclass_f1_score(torch.tensor(labels), torch.tensor(preds), num_classes=4)
# Out:
# tensor(0.8839)
