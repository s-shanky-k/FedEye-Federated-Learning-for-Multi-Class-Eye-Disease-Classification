# %% [markdown]
# # Federated Learning In ResNet - Eye Disease Classifications

# %% [markdown]
# ### Installing dependencies

# %%
# !pip install flwr["simulation"]==0.18.0 torch torchvision
# Out:
# Collecting flwr[simulation]==0.18.0
#   Downloading flwr-0.18.0-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.2/106.2 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.0.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.15.1)
# Collecting google<3.0.0,>=2.0.3 (from flwr[simulation]==0.18.0)
#   Downloading google-2.0.3-py2.py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 3.5 MB/s eta 0:00:00
# Collecting grpcio<=1.43.0,>=1.27.2 (from flwr[simulation]==0.18.0)
#   Downloading grpcio-1.43.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 21.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>=1.19.0 in /opt/conda/lib/python3.10/site-packages (from flwr[simulation]==0.18.0) (1.24.3)
# Requirement already satisfied: protobuf<4.0.0,>=3.12.1 in /opt/conda/lib/python3.10/site-packages (from flwr[simulation]==0.18.0) (3.20.3)
# Collecting ray[default]<2.0.0,>=1.9.2 (from flwr[simulation]==0.18.0)
#   Downloading ray-1.13.0-cp310-cp310-manylinux2014_x86_64.whl (54.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 MB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (10.1.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from google<3.0.0,>=2.0.3->flwr[simulation]==0.18.0) (4.12.2)
# Requirement already satisfied: six>=1.5.2 in /opt/conda/lib/python3.10/site-packages (from grpcio<=1.43.0,>=1.27.2->flwr[simulation]==0.18.0) (1.16.0)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (23.1.0)
# Collecting click<=8.0.4,>=7.0 (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0)
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 997.2 kB/s eta 0:00:00
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (4.19.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (1.0.5)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (6.0.1)
# Requirement already satisfied: aiosignal in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (1.3.1)
# Requirement already satisfied: frozenlist in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (1.4.0)
# Requirement already satisfied: virtualenv in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (20.21.0)
# Requirement already satisfied: aiohttp>=3.7 in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (3.8.5)
# Requirement already satisfied: aiohttp-cors in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.7.0)
# Requirement already satisfied: colorful in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.5.5)
# Requirement already satisfied: py-spy>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.3.14)
# Requirement already satisfied: gpustat>=1.0.0b1 in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (1.0.0)
# Requirement already satisfied: opencensus in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.11.2)
# Collecting prometheus-client<0.14.0,>=0.7.1 (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0)
#   Downloading prometheus_client-0.13.1-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: smart-open in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (6.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (1.9.2)
# Requirement already satisfied: nvidia-ml-py<=11.495.46,>=11.450.129 in /opt/conda/lib/python3.10/site-packages (from gpustat>=1.0.0b1->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (11.495.46)
# Requirement already satisfied: psutil>=5.6.0 in /opt/conda/lib/python3.10/site-packages (from gpustat>=1.0.0b1->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (5.9.3)
# Requirement already satisfied: blessed>=1.17.1 in /opt/conda/lib/python3.10/site-packages (from gpustat>=1.0.0b1->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (1.20.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->google<3.0.0,>=2.0.3->flwr[simulation]==0.18.0) (2.3.2.post1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.9.2)
# Requirement already satisfied: opencensus-context>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from opencensus->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from opencensus->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (2.11.1)
# Requirement already satisfied: distlib<1,>=0.3.6 in /opt/conda/lib/python3.10/site-packages (from virtualenv->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.3.7)
# Collecting platformdirs<4,>=2.4 (from virtualenv->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0)
#   Obtaining dependency information for platformdirs<4,>=2.4 from https://files.pythonhosted.org/packages/56/29/3ec311dc18804409ecf0d2b09caa976f3ae6215559306b5b530004e11156/platformdirs-3.11.0-py3-none-any.whl.metadata
#   Downloading platformdirs-3.11.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: wcwidth>=0.1.4 in /opt/conda/lib/python3.10/site-packages (from blessed>=1.17.1->gpustat>=1.0.0b1->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.2.6)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (1.60.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (2.22.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (4.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.4.8)
# Downloading platformdirs-3.11.0-py3-none-any.whl (17 kB)
# Installing collected packages: prometheus-client, platformdirs, grpcio, click, google, flwr, ray
#   Attempting uninstall: prometheus-client
#     Found existing installation: prometheus-client 0.17.1
#     Uninstalling prometheus-client-0.17.1:
#       Successfully uninstalled prometheus-client-0.17.1
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 4.1.0
#     Uninstalling platformdirs-4.1.0:
#       Successfully uninstalled platformdirs-4.1.0
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.51.1
#     Uninstalling grpcio-1.51.1:
#       Successfully uninstalled grpcio-1.51.1
#   Attempting uninstall: click
#     Found existing installation: click 8.1.7
#     Uninstalling click-8.1.7:
#       Successfully uninstalled click-8.1.7
#   Attempting uninstall: ray
#     Found existing installation: ray 2.6.3
#     Uninstalling ray-2.6.3:
#       Successfully uninstalled ray-2.6.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.7 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# dask 2023.12.0 requires click>=8.1, but you have click 8.0.4 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2023.12.0 which is incompatible.
# dask-cuda 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.12.0 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.3 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2023.12.0 which is incompatible.
# dask-cudf 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.12.0 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.3 which is incompatible.
# fitter 1.6.0 requires click<9.0.0,>=8.1.6, but you have click 8.0.4 which is incompatible.
# flask 3.0.0 requires click>=8.1.3, but you have click 8.0.4 which is incompatible.
# google-cloud-pubsub 2.18.3 requires grpcio<2.0dev,>=1.51.3, but you have grpcio 1.43.0 which is incompatible.
# grpc-google-iam-v1 0.12.6 requires grpcio<2.0.0dev,>=1.44.0, but you have grpcio 1.43.0 which is incompatible.
# grpcio-status 1.48.1 requires grpcio>=1.48.1, but you have grpcio 1.43.0 which is incompatible.
# jupyterlab 4.0.5 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.0.1 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.0.1 requires jupyterlab<5.0.0a0,>=4.0.6, but you have jupyterlab 4.0.5 which is incompatible.
# kfp 2.0.1 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2023.12.0 which is incompatible.
# raft-dask 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.12.0 which is incompatible.
# tensorboard 2.13.0 requires grpcio>=1.48.2, but you have grpcio 1.43.0 which is incompatible.
# tensorflowjs 4.14.0 requires packaging~=23.1, but you have packaging 21.3 which is incompatible.
# Successfully installed click-8.0.4 flwr-0.18.0 google-2.0.3 grpcio-1.43.0 platformdirs-3.11.0 prometheus-client-0.13.1 ray-1.13.0

# %%
from collections import OrderedDict
from typing import Dict, List, Optional, Tuple

import flwr as fl
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, utils
torch.manual_seed(42)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Training on {DEVICE}")
# Out:
# Training on cuda

# %% [markdown]
# ### Data loading

# %%
class EyeImageDataset(torch.utils.data.Dataset):
    def __init__(self, root_dir, transform=None):
        self.dataset = datasets.ImageFolder(root=root_dir, transform=transform)
        self.classes = self.dataset.classes

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        return self.dataset[idx]

# %%
root_directory = '/kaggle/input/dataset/'

data_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize(size = (224, 224)),
    transforms.RandomRotation(degrees=5),
    transforms.RandomHorizontalFlip(p=0.5),
])

dataset = EyeImageDataset(root_dir=root_directory, transform=data_transform)

# %%
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [int(len(dataset)*0.9), len(dataset)-int(len(dataset)*0.9)])

# %% [markdown]
# ## Setting number of clients to simulate Federated Learning

# %%
NUM_CLIENTS = 3

# %%
num_clients = NUM_CLIENTS

# Split training set into `num_clients` partitions to simulate different local datasets
partition_size = len(train_dataset) // num_clients
lengths = [partition_size] * num_clients
datasets = random_split(train_dataset, lengths, torch.Generator().manual_seed(42))

# Split each partition into train/val and create DataLoader
train_loaders = []
val_loaders = []
for ds in datasets:
    len_val = len(ds) // 10  # 10 % validation set
    len_train = len(ds) - len_val
    lengths = [len_train, len_val]
    ds_train, ds_val = random_split(ds, lengths, torch.Generator().manual_seed(42))
    train_loaders.append(DataLoader(ds_train, batch_size=8, shuffle=True))
    val_loaders.append(DataLoader(ds_val, batch_size=8,shuffle=True))
test_loader = DataLoader(test_dataset, batch_size=8)

# %% [markdown]
# ### Model training/evaluation

# %%
import torch
import torchvision.models as models
from torchvision.models import resnet50, ResNet50_Weights, resnet18, ResNet18_Weights
import torch.nn as nn
import tqdm

# %%
model = models.resnet50(weights = ResNet50_Weights.IMAGENET1K_V1)

ct = 0
for child in model.children():
    ct += 1
    if ct < 7:
        for param in child.parameters():
            param.requires_grad = False
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 227MB/s]

# %%
# modify the classifier layer
model.fc = nn.Sequential(nn.Linear(2048, 1024), nn.ReLU(), nn.Linear(1024, 1024), nn.ReLU(), nn.Linear(1024,4))

# %%
model = model.to(DEVICE)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=1024, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=1024, out_features=4, bias=True)
#   )
# )

# %%
def evaluate(model, data_loader, criterion):
    """Evaluate the model on the given dataset."""
    # Set the model to evaluation mode.
    model.eval()
    correct = 0
    val_loss = 0
    count = 0
    # The `torch.no_grad()` context will turn off gradients for efficiency.
    with torch.no_grad():
        for images, labels in (data_loader):
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            output = model(images)
            pred = output.argmax(dim=1)
            loss = criterion(output, labels)
            correct += (pred == labels).sum().item()
            val_loss += loss.item() 
            count += 1
    return correct / len(data_loader.dataset), val_loss/count


def train(model, n_epoch, optimizer, scheduler, criterion, train_loader, valid_loader):
    """Train the model on the given dataset."""
    loss_ref = float('inf')
    for epoch in range(n_epoch):
        # Set the model to training mode.
        model.train()
        for step, (images, labels) in enumerate(train_loader):
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            # 1. Clear previous gradients.
            optimizer.zero_grad()
            # 2. Forward pass. Calculate the output of the model.
            output = model(images)
            # 3. Calculate the loss.
            loss = criterion(output, labels)
            # 4. Calculate the gradients. PyTorch does this for us!
            loss.backward()
            # 5. Update the model parameters.
            optimizer.step()
            if step % 10 == 0:
                print(f"Epoch {epoch}, Step {step}, Loss {loss.item():.4f}")
        
        acc, val_loss = evaluate(model, valid_loader, criterion)
        scheduler.step(val_loss)
        print(f"Epoch {epoch}, Valid Accuracy {acc * 100:.2f}%") 
        
        if val_loss < loss_ref:
            patience = 5
            loss_ref = val_loss
        else:
            if patience == 0:
                print(f"[Early Stopping] Epoch {epoch}, Valid Accuracy {acc * 100:.2f}%, Valid Loss {val_loss:.4f}")
                return
            print(f"[INFO] Patience {patience} remaining")
            patience-=1

# %%
def get_parameters(net) -> List[np.ndarray]:
    return [val.cpu().numpy() for _, val in net.state_dict().items()]


def set_parameters(net, parameters: List[np.ndarray]):
    params_dict = zip(net.state_dict().keys(), parameters)
    state_dict = OrderedDict(
            {
                k: torch.Tensor(v) if v.shape != torch.Size([]) else torch.Tensor([0])
                for k, v in params_dict
            }
        )
    net.load_state_dict(state_dict, strict=True)

def test(net, testloader):
    """Evaluate the network on the entire test set."""
    criterion = torch.nn.CrossEntropyLoss()
    correct, total, loss = 0, 0, 0.0
    net.eval()
    with torch.no_grad():
        for images, labels in testloader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = net(images)
            loss += criterion(outputs, labels).item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    loss /= len(testloader.dataset)
    accuracy = correct / total
    return loss, accuracy

# %% [markdown]
# ### Flower client
#
# Setting flower client. These flower clients represent a client on the federated learning model.

# %%
from logging import INFO, DEBUG
from flwr.common.logger import log

class FlowerClient(fl.client.NumPyClient):
    def __init__(self, cid, net, trainloader, valloader):
        self.cid = cid
        self.model = model.to(DEVICE)
        self.trainloader = trainloader
        self.valloader = valloader

    def get_parameters(self):
        print(f"[Client {self.cid}] get_parameters")
        return [val.cpu().numpy() for _, val in self.model.state_dict().items()]
    
    def set_parameters(self, parameters: List[np.ndarray]) -> None:
        # Set model parameters from a list of NumPy ndarrays
        params_dict = zip(self.model.state_dict().keys(), parameters)
        state_dict = OrderedDict(
                    {
                        k: torch.Tensor(v) if v.shape != torch.Size([]) else torch.Tensor([0])
                        for k, v in params_dict
                    }
                )
        self.model.load_state_dict(state_dict, strict=True)

    def fit(self, parameters, config):
        print(f"[Client {self.cid}] fit, config: {config}")
        self.set_parameters(parameters)
        lr = 1e-3
        gamma = 0.9
        criterion = nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=lr)
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, verbose=True)

        n_epoch = 20
        train(self.model, n_epoch, optimizer, scheduler,criterion,self.trainloader, self.valloader)
        return self.get_parameters(), len(self.trainloader), {}

    def evaluate(self, parameters, config):
        print(f"[Client {self.cid}] evaluate, config: {config}")
        self.set_parameters(parameters)
        criterion = nn.CrossEntropyLoss()
        accuracy, loss = evaluate(self.model, self.valloader, criterion)
        return float(loss), len(self.valloader), {"accuracy": float(accuracy)}


def client_fn(cid) -> FlowerClient:
    train_loader = train_loaders[int(cid)]
    val_loader = val_loaders[int(cid)]
    return FlowerClient(cid, model, train_loader, val_loader)

# %% [markdown]
# ## Server Side Evaluation
# We evalaute the accumulated model on the server after every federated round against the validation and test set

# %%
def get_evaluate_fn():

    def evaluate(
        parameters:  List[np.ndarray],
    ) -> Optional[Tuple[float, Dict[str, fl.common.Scalar]]]:
        params_dict = zip(model.state_dict().keys(), parameters)
        state_dict = OrderedDict({k: torch.tensor(v) for k, v in params_dict})
        model.load_state_dict(state_dict, strict=True)
        val_loss, val_accuracy = test(model, val_loaders[0])
        test_loss, test_accuracy = test(model, test_loader)
        return val_loss, {"val_accuracy": val_accuracy, "test_accuracy": test_accuracy}

    return evaluate
# The `evaluate` function will be by Flower called after every round
def evaluate_server(
    parameters: List[np.ndarray],
) -> Optional[Tuple[float, Dict[str, fl.common.Scalar]]]:
    net = model.to(DEVICE)
    valloader = val_loaders[0]
    set_parameters(net, parameters)  # Update model with the latest parameters
    loss, accuracy = test(net, valloader)
    print(f"Server-side evaluation loss {loss} / accuracy {accuracy}")
    return loss, {"accuracy": accuracy}

# %% [markdown]
# ## Server Side Initialization and Simulation
# We make use of FedAdagrad to accumulate the paramters from all the clients on the server.

# %%
model_params = get_parameters(model.to(DEVICE))
strategy = fl.server.strategy.FedAdagrad(
    fraction_fit=0.3,
    fraction_eval=0.3,
    min_fit_clients=2,
    min_eval_clients=2,
    min_available_clients=NUM_CLIENTS,
    initial_parameters=fl.common.weights_to_parameters(get_parameters(model.to(DEVICE))),
    eval_fn=get_evaluate_fn(),  # Pass the evaluation function
    
)

#Start Simulation
res = fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=NUM_CLIENTS,
    num_rounds=10,
    strategy=strategy,
    client_resources = {'num_cpus': 4, 'num_gpus': 2}
)
# Out:
# INFO flower 2023-12-12 00:30:13,475 | app.py:144 | Ray initialized with resources: {'accelerator_type:T4': 1.0, 'memory': 18804609024.0, 'CPU': 4.0, 'GPU': 2.0, 'node:172.19.2.2': 1.0, 'object_store_memory': 9402304512.0}
# INFO flower 2023-12-12 00:30:13,477 | app.py:153 | Starting Flower simulation running: {'num_rounds': 10}
# INFO flower 2023-12-12 00:30:13,481 | server.py:128 | Initializing global parameters
# INFO flower 2023-12-12 00:30:13,484 | server.py:323 | Using initial parameters provided by strategy
# INFO flower 2023-12-12 00:30:13,485 | server.py:130 | Evaluating initial parameters
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# INFO flower 2023-12-12 00:30:36,349 | server.py:133 | initial parameters (loss, other metrics): 0.17667243310383388, {'val_accuracy': 0.36507936507936506, 'test_accuracy': 0.36729857819905215}
# INFO flower 2023-12-12 00:30:36,350 | server.py:143 | FL starting
# DEBUG flower 2023-12-12 00:30:36,350 | server.py:265 | fit_round: strategy sampled 2 clients (out of 3)
# (launch_and_fit pid=303) [Client 2] fit, config: {}
# (launch_and_fit pid=303) /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# (launch_and_fit pid=303)   warnings.warn(
# (launch_and_fit pid=303) Epoch 0, Step 0, Loss 1.4211
# (launch_and_fit pid=303) Epoch 0, Step 10, Loss 1.4997
# (launch_and_fit pid=303) Epoch 0, Step 20, Loss 1.0152
# (launch_and_fit pid=303) Epoch 0, Step 30, Loss 1.1895
# (launch_and_fit pid=303) Epoch 0, Step 40, Loss 1.0062
# (launch_and_fit pid=303) Epoch 0, Step 50, Loss 1.1472
# (launch_and_fit pid=303) Epoch 0, Step 60, Loss 0.8010
# (launch_and_fit pid=303) Epoch 0, Step 70, Loss 0.9970
# (launch_and_fit pid=303) Epoch 0, Step 80, Loss 0.7472
# (launch_and_fit pid=303) Epoch 0, Step 90, Loss 0.9567
# (launch_and_fit pid=303) Epoch 0, Step 100, Loss 1.2817
# (launch_and_fit pid=303) Epoch 0, Step 110, Loss 1.3253
# (launch_and_fit pid=303) Epoch 0, Step 120, Loss 0.9254
# (launch_and_fit pid=303) Epoch 0, Step 130, Loss 0.6892
# (launch_and_fit pid=303) Epoch 0, Step 140, Loss 0.5527
# (launch_and_fit pid=303) Epoch 0, Valid Accuracy 68.25%
# (launch_and_fit pid=303) Epoch 1, Step 0, Loss 1.0763
# (launch_and_fit pid=303) Epoch 1, Step 10, Loss 0.3589
# (launch_and_fit pid=303) Epoch 1, Step 20, Loss 0.6376
# (launch_and_fit pid=303) Epoch 1, Step 30, Loss 0.8128
# (launch_and_fit pid=303) Epoch 1, Step 40, Loss 0.2541
# (launch_and_fit pid=303) Epoch 1, Step 50, Loss 0.9246
# (launch_and_fit pid=303) Epoch 1, Step 60, Loss 0.4836
# (launch_and_fit pid=303) Epoch 1, Step 70, Loss 0.3253
# (launch_and_fit pid=303) Epoch 1, Step 80, Loss 0.5111
# (launch_and_fit pid=303) Epoch 1, Step 90, Loss 1.2274
# (launch_and_fit pid=303) Epoch 1, Step 100, Loss 0.3935
# (launch_and_fit pid=303) Epoch 1, Step 110, Loss 0.3628
# (launch_and_fit pid=303) Epoch 1, Step 120, Loss 0.5327
# (launch_and_fit pid=303) Epoch 1, Step 130, Loss 0.8456
# (launch_and_fit pid=303) Epoch 1, Step 140, Loss 0.5882
# (launch_and_fit pid=303) Epoch 1, Valid Accuracy 69.84%
# (launch_and_fit pid=303) Epoch 2, Step 0, Loss 0.6718
# (launch_and_fit pid=303) Epoch 2, Step 10, Loss 0.5757
# (launch_and_fit pid=303) Epoch 2, Step 20, Loss 0.7061
# (launch_and_fit pid=303) Epoch 2, Step 30, Loss 0.3473
# (launch_and_fit pid=303) Epoch 2, Step 40, Loss 0.3613
# (launch_and_fit pid=303) Epoch 2, Step 50, Loss 0.2125
# (launch_and_fit pid=303) Epoch 2, Step 60, Loss 0.3298
# (launch_and_fit pid=303) Epoch 2, Step 70, Loss 0.6857
# (launch_and_fit pid=303) Epoch 2, Step 80, Loss 0.4398
# (launch_and_fit pid=303) Epoch 2, Step 90, Loss 0.3632
# (launch_and_fit pid=303) Epoch 2, Step 100, Loss 0.2790
# (launch_and_fit pid=303) Epoch 2, Step 110, Loss 0.5503
# (launch_and_fit pid=303) Epoch 2, Step 120, Loss 0.9010
# (launch_and_fit pid=303) Epoch 2, Step 130, Loss 0.7462
# (launch_and_fit pid=303) Epoch 2, Step 140, Loss 0.6543
# (launch_and_fit pid=303) Epoch 2, Valid Accuracy 78.57%
# (launch_and_fit pid=303) Epoch 3, Step 0, Loss 0.4978
# (launch_and_fit pid=303) Epoch 3, Step 10, Loss 0.2580
# (launch_and_fit pid=303) Epoch 3, Step 20, Loss 0.8262
# (launch_and_fit pid=303) Epoch 3, Step 30, Loss 0.8477
# (launch_and_fit pid=303) Epoch 3, Step 40, Loss 0.5089
# (launch_and_fit pid=303) Epoch 3, Step 50, Loss 0.5655
# (launch_and_fit pid=303) Epoch 3, Step 60, Loss 0.7238
# (launch_and_fit pid=303) Epoch 3, Step 70, Loss 0.3773
# (launch_and_fit pid=303) Epoch 3, Step 80, Loss 0.7391
# (launch_and_fit pid=303) Epoch 3, Step 90, Loss 0.7203
# (launch_and_fit pid=303) Epoch 3, Step 100, Loss 0.1986
# (launch_and_fit pid=303) Epoch 3, Step 110, Loss 0.9580
# (launch_and_fit pid=303) Epoch 3, Step 120, Loss 0.1799
# (launch_and_fit pid=303) Epoch 3, Step 130, Loss 0.5272
# (launch_and_fit pid=303) Epoch 3, Step 140, Loss 0.3138
# (launch_and_fit pid=303) Epoch 3, Valid Accuracy 81.75%
# (launch_and_fit pid=303) [INFO] Patience 5 remaining
# (launch_and_fit pid=303) Epoch 4, Step 0, Loss 0.5048
# (launch_and_fit pid=303) Epoch 4, Step 10, Loss 0.4190
# (launch_and_fit pid=303) Epoch 4, Step 20, Loss 0.0382
# (launch_and_fit pid=303) Epoch 4, Step 30, Loss 0.5589
# (launch_and_fit pid=303) Epoch 4, Step 40, Loss 0.4632
# (launch_and_fit pid=303) Epoch 4, Step 50, Loss 0.2815
# (launch_and_fit pid=303) Epoch 4, Step 60, Loss 0.7663
# (launch_and_fit pid=303) Epoch 4, Step 70, Loss 0.1641
# (launch_and_fit pid=303) Epoch 4, Step 80, Loss 0.7911
# (launch_and_fit pid=303) Epoch 4, Step 90, Loss 0.8968
# (launch_and_fit pid=303) Epoch 4, Step 100, Loss 0.2509
# (launch_and_fit pid=303) Epoch 4, Step 110, Loss 0.3197
# (launch_and_fit pid=303) Epoch 4, Step 120, Loss 0.1100
# (launch_and_fit pid=303) Epoch 4, Step 130, Loss 0.1338
# (launch_and_fit pid=303) Epoch 4, Step 140, Loss 0.6238
# (launch_and_fit pid=303) Epoch 4, Valid Accuracy 80.95%
# (launch_and_fit pid=303) [INFO] Patience 4 remaining
# (launch_and_fit pid=303) Epoch 5, Step 0, Loss 0.2106
# (launch_and_fit pid=303) Epoch 5, Step 10, Loss 0.7092
# (launch_and_fit pid=303) Epoch 5, Step 20, Loss 0.2879
# (launch_and_fit pid=303) Epoch 5, Step 30, Loss 0.2278
# (launch_and_fit pid=303) Epoch 5, Step 40, Loss 0.4412
# (launch_and_fit pid=303) Epoch 5, Step 50, Loss 1.1558
# (launch_and_fit pid=303) Epoch 5, Step 60, Loss 0.2103
# (launch_and_fit pid=303) Epoch 5, Step 70, Loss 0.3217
# (launch_and_fit pid=303) Epoch 5, Step 80, Loss 0.2460
# (launch_and_fit pid=303) Epoch 5, Step 90, Loss 0.3683
# (launch_and_fit pid=303) Epoch 5, Step 100, Loss 0.7395
# (launch_and_fit pid=303) Epoch 5, Step 110, Loss 0.2088
# (launch_and_fit pid=303) Epoch 5, Step 120, Loss 0.1844
# (launch_and_fit pid=303) Epoch 5, Step 130, Loss 0.3791
# (launch_and_fit pid=303) Epoch 5, Step 140, Loss 0.4262
# (launch_and_fit pid=303) Epoch 5, Valid Accuracy 77.78%
# (launch_and_fit pid=303) [INFO] Patience 3 remaining
# (launch_and_fit pid=303) Epoch 6, Step 0, Loss 0.6502
# (launch_and_fit pid=303) Epoch 6, Step 10, Loss 0.9863
# (launch_and_fit pid=303) Epoch 6, Step 20, Loss 0.3302
# (launch_and_fit pid=303) Epoch 6, Step 30, Loss 0.1563
# (launch_and_fit pid=303) Epoch 6, Step 40, Loss 0.4218
# (launch_and_fit pid=303) Epoch 6, Step 50, Loss 0.5711
# (launch_and_fit pid=303) Epoch 6, Step 60, Loss 0.2884
# (launch_and_fit pid=303) Epoch 6, Step 70, Loss 0.2274
# (launch_and_fit pid=303) Epoch 6, Step 80, Loss 0.8425
# (launch_and_fit pid=303) Epoch 6, Step 90, Loss 0.1037
# (launch_and_fit pid=303) Epoch 6, Step 100, Loss 0.2843
# (launch_and_fit pid=303) Epoch 6, Step 110, Loss 0.1720
# (launch_and_fit pid=303) Epoch 6, Step 120, Loss 0.6071
# (launch_and_fit pid=303) Epoch 6, Step 130, Loss 0.3160
# (launch_and_fit pid=303) Epoch 6, Step 140, Loss 0.8538
# (launch_and_fit pid=303) Epoch 6, Valid Accuracy 82.54%
# (launch_and_fit pid=303) Epoch 7, Step 0, Loss 0.5394
# (launch_and_fit pid=303) Epoch 7, Step 10, Loss 0.1818
# (launch_and_fit pid=303) Epoch 7, Step 20, Loss 0.1249
# (launch_and_fit pid=303) Epoch 7, Step 30, Loss 0.1491
# (launch_and_fit pid=303) Epoch 7, Step 40, Loss 0.5773
# (launch_and_fit pid=303) Epoch 7, Step 50, Loss 0.2200
# (launch_and_fit pid=303) Epoch 7, Step 60, Loss 0.0975
# (launch_and_fit pid=303) Epoch 7, Step 70, Loss 0.0425
# (launch_and_fit pid=303) Epoch 7, Step 80, Loss 0.8589
# (launch_and_fit pid=303) Epoch 7, Step 90, Loss 0.0391
# (launch_and_fit pid=303) Epoch 7, Step 100, Loss 0.5036
# (launch_and_fit pid=303) Epoch 7, Step 110, Loss 0.3262
# (launch_and_fit pid=303) Epoch 7, Step 120, Loss 1.3939
# (launch_and_fit pid=303) Epoch 7, Step 130, Loss 0.2241
# (launch_and_fit pid=303) Epoch 7, Step 140, Loss 0.6193
# (launch_and_fit pid=303) Epoch 7, Valid Accuracy 81.75%
# (launch_and_fit pid=303) Epoch 8, Step 0, Loss 0.2069
# (launch_and_fit pid=303) Epoch 8, Step 10, Loss 0.4280
# (launch_and_fit pid=303) Epoch 8, Step 20, Loss 0.2293
# (launch_and_fit pid=303) Epoch 8, Step 30, Loss 0.2053
# (launch_and_fit pid=303) Epoch 8, Step 40, Loss 0.3664
# (launch_and_fit pid=303) Epoch 8, Step 50, Loss 0.8725
# (launch_and_fit pid=303) Epoch 8, Step 60, Loss 0.4741
# (launch_and_fit pid=303) Epoch 8, Step 70, Loss 0.1632
# (launch_and_fit pid=303) Epoch 8, Step 80, Loss 0.4334
# (launch_and_fit pid=303) Epoch 8, Step 90, Loss 0.8605
# (launch_and_fit pid=303) Epoch 8, Step 100, Loss 0.3710
# (launch_and_fit pid=303) Epoch 8, Step 110, Loss 0.8030
# (launch_and_fit pid=303) Epoch 8, Step 120, Loss 0.3302
# (launch_and_fit pid=303) Epoch 8, Step 130, Loss 0.7133
# (launch_and_fit pid=303) Epoch 8, Step 140, Loss 0.5875
# (launch_and_fit pid=303) Epoch 8, Valid Accuracy 80.95%
# (launch_and_fit pid=303) [INFO] Patience 5 remaining
# (launch_and_fit pid=303) Epoch 9, Step 0, Loss 0.3510
# (launch_and_fit pid=303) Epoch 9, Step 10, Loss 0.1179
# (launch_and_fit pid=303) Epoch 9, Step 20, Loss 1.2283
# (launch_and_fit pid=303) Epoch 9, Step 30, Loss 0.3306
# (launch_and_fit pid=303) Epoch 9, Step 40, Loss 0.4387
# (launch_and_fit pid=303) Epoch 9, Step 50, Loss 0.5600
# (launch_and_fit pid=303) Epoch 9, Step 60, Loss 0.4013
# (launch_and_fit pid=303) Epoch 9, Step 70, Loss 0.1604
# (launch_and_fit pid=303) Epoch 9, Step 80, Loss 0.2556
# (launch_and_fit pid=303) Epoch 9, Step 90, Loss 0.3569
# (launch_and_fit pid=303) Epoch 9, Step 100, Loss 0.3796
# (launch_and_fit pid=303) Epoch 9, Step 110, Loss 0.1529
# (launch_and_fit pid=303) Epoch 9, Step 120, Loss 0.0795
# (launch_and_fit pid=303) Epoch 9, Step 130, Loss 0.2221
# (launch_and_fit pid=303) Epoch 9, Step 140, Loss 0.0906
# (launch_and_fit pid=303) Epoch 9, Valid Accuracy 83.33%
# (launch_and_fit pid=303) [INFO] Patience 4 remaining
# (launch_and_fit pid=303) Epoch 10, Step 0, Loss 0.4570
# (launch_and_fit pid=303) Epoch 10, Step 10, Loss 0.0564
# (launch_and_fit pid=303) Epoch 10, Step 20, Loss 0.0974
# (launch_and_fit pid=303) Epoch 10, Step 30, Loss 0.1558
# (launch_and_fit pid=303) Epoch 10, Step 40, Loss 0.0763
# (launch_and_fit pid=303) Epoch 10, Step 50, Loss 0.0695
# (launch_and_fit pid=303) Epoch 10, Step 60, Loss 0.4157
# (launch_and_fit pid=303) Epoch 10, Step 70, Loss 0.2841
# (launch_and_fit pid=303) Epoch 10, Step 80, Loss 0.8008
# (launch_and_fit pid=303) Epoch 10, Step 90, Loss 0.4510
# (launch_and_fit pid=303) Epoch 10, Step 100, Loss 0.4727
# (launch_and_fit pid=303) Epoch 10, Step 110, Loss 0.3410
# (launch_and_fit pid=303) Epoch 10, Step 120, Loss 0.7677
# (launch_and_fit pid=303) Epoch 10, Step 130, Loss 0.1414
# (launch_and_fit pid=303) Epoch 10, Step 140, Loss 0.4138
# (launch_and_fit pid=303) Epoch 10, Valid Accuracy 82.54%
# (launch_and_fit pid=303) [INFO] Patience 3 remaining
# (launch_and_fit pid=303) Epoch 11, Step 0, Loss 0.0978
# (launch_and_fit pid=303) Epoch 11, Step 10, Loss 0.4033
# (launch_and_fit pid=303) Epoch 11, Step 20, Loss 0.4395
# (launch_and_fit pid=303) Epoch 11, Step 30, Loss 0.2589
# (launch_and_fit pid=303) Epoch 11, Step 40, Loss 0.1594
# (launch_and_fit pid=303) Epoch 11, Step 50, Loss 0.3248
# (launch_and_fit pid=303) Epoch 11, Step 60, Loss 0.4348
# (launch_and_fit pid=303) Epoch 11, Step 70, Loss 0.2456
# (launch_and_fit pid=303) Epoch 11, Step 80, Loss 0.0693
# (launch_and_fit pid=303) Epoch 11, Step 90, Loss 0.3394
# (launch_and_fit pid=303) Epoch 11, Step 100, Loss 0.4847
# (launch_and_fit pid=303) Epoch 11, Step 110, Loss 0.0687
# (launch_and_fit pid=303) Epoch 11, Step 120, Loss 0.5957
# (launch_and_fit pid=303) Epoch 11, Step 130, Loss 0.1778
# (launch_and_fit pid=303) Epoch 11, Step 140, Loss 0.4083
# (launch_and_fit pid=303) Epoch 11, Valid Accuracy 80.16%
# (launch_and_fit pid=303) Epoch 12, Step 0, Loss 0.0996
# (launch_and_fit pid=303) Epoch 12, Step 10, Loss 0.3824
# (launch_and_fit pid=303) Epoch 12, Step 20, Loss 0.1358
# (launch_and_fit pid=303) Epoch 12, Step 30, Loss 1.0720
# (launch_and_fit pid=303) Epoch 12, Step 40, Loss 0.2249
# (launch_and_fit pid=303) Epoch 12, Step 50, Loss 0.2050
# (launch_and_fit pid=303) Epoch 12, Step 60, Loss 0.6582
# (launch_and_fit pid=303) Epoch 12, Step 70, Loss 0.1464
# (launch_and_fit pid=303) Epoch 12, Step 80, Loss 0.0781
# (launch_and_fit pid=303) Epoch 12, Step 90, Loss 0.0975
# (launch_and_fit pid=303) Epoch 12, Step 100, Loss 0.1074
# (launch_and_fit pid=303) Epoch 12, Step 110, Loss 0.1862
# (launch_and_fit pid=303) Epoch 12, Step 120, Loss 0.1060
# (launch_and_fit pid=303) Epoch 12, Step 130, Loss 0.1053
# (launch_and_fit pid=303) Epoch 12, Step 140, Loss 0.2993
# (launch_and_fit pid=303) Epoch 12, Valid Accuracy 85.71%
# (launch_and_fit pid=303) Epoch 13, Step 0, Loss 0.0709
# (launch_and_fit pid=303) Epoch 13, Step 10, Loss 0.4534
# (launch_and_fit pid=303) Epoch 13, Step 20, Loss 0.4850
# (launch_and_fit pid=303) Epoch 13, Step 30, Loss 0.0675
# (launch_and_fit pid=303) Epoch 13, Step 40, Loss 0.5160
# (launch_and_fit pid=303) Epoch 13, Step 50, Loss 0.1134
# (launch_and_fit pid=303) Epoch 13, Step 60, Loss 1.1134
# (launch_and_fit pid=303) Epoch 13, Step 70, Loss 0.3155
# (launch_and_fit pid=303) Epoch 13, Step 80, Loss 0.7450
# (launch_and_fit pid=303) Epoch 13, Step 90, Loss 0.1833
# (launch_and_fit pid=303) Epoch 13, Step 100, Loss 0.0650
# (launch_and_fit pid=303) Epoch 13, Step 110, Loss 0.0563
# (launch_and_fit pid=303) Epoch 13, Step 120, Loss 0.0523
# (launch_and_fit pid=303) Epoch 13, Step 130, Loss 0.3434
# (launch_and_fit pid=303) Epoch 13, Step 140, Loss 0.3473
# (launch_and_fit pid=303) Epoch 13, Valid Accuracy 82.54%
# (launch_and_fit pid=303) [INFO] Patience 5 remaining
# (launch_and_fit pid=303) Epoch 14, Step 0, Loss 0.4047
# (launch_and_fit pid=303) Epoch 14, Step 10, Loss 0.1782
# (launch_and_fit pid=303) Epoch 14, Step 20, Loss 0.4416
# (launch_and_fit pid=303) Epoch 14, Step 30, Loss 0.0895
# (launch_and_fit pid=303) Epoch 14, Step 40, Loss 0.4128
# (launch_and_fit pid=303) Epoch 14, Step 50, Loss 0.1625
# (launch_and_fit pid=303) Epoch 14, Step 60, Loss 0.4222
# (launch_and_fit pid=303) Epoch 14, Step 70, Loss 0.2293
# (launch_and_fit pid=303) Epoch 14, Step 80, Loss 0.4792
# (launch_and_fit pid=303) Epoch 14, Step 90, Loss 0.7883
# (launch_and_fit pid=303) Epoch 14, Step 100, Loss 0.4922
# (launch_and_fit pid=303) Epoch 14, Step 110, Loss 0.6350
# (launch_and_fit pid=303) Epoch 14, Step 120, Loss 0.9232
# (launch_and_fit pid=303) Epoch 14, Step 130, Loss 0.4809
# (launch_and_fit pid=303) Epoch 14, Step 140, Loss 0.4172
# (launch_and_fit pid=303) Epoch 14, Valid Accuracy 80.95%
# (launch_and_fit pid=303) [INFO] Patience 4 remaining
# (launch_and_fit pid=303) Epoch 15, Step 0, Loss 0.3039
# (launch_and_fit pid=303) Epoch 15, Step 10, Loss 0.1374
# (launch_and_fit pid=303) Epoch 15, Step 20, Loss 0.2820
# (launch_and_fit pid=303) Epoch 15, Step 30, Loss 0.0357
# (launch_and_fit pid=303) Epoch 15, Step 40, Loss 0.0979
# (launch_and_fit pid=303) Epoch 15, Step 50, Loss 0.6317
# (launch_and_fit pid=303) Epoch 15, Step 60, Loss 0.1735
# (launch_and_fit pid=303) Epoch 15, Step 70, Loss 0.1755
# (launch_and_fit pid=303) Epoch 15, Step 80, Loss 0.3230
# (launch_and_fit pid=303) Epoch 15, Step 90, Loss 0.1749
# (launch_and_fit pid=303) Epoch 15, Step 100, Loss 0.2516
# (launch_and_fit pid=303) Epoch 15, Step 110, Loss 0.0871
# (launch_and_fit pid=303) Epoch 15, Step 120, Loss 0.0527
# (launch_and_fit pid=303) Epoch 15, Step 130, Loss 0.2236
# (launch_and_fit pid=303) Epoch 15, Step 140, Loss 0.2270
# (launch_and_fit pid=303) Epoch 15, Valid Accuracy 86.51%
# (launch_and_fit pid=303) [INFO] Patience 3 remaining
# (launch_and_fit pid=303) Epoch 16, Step 0, Loss 0.1005
# (launch_and_fit pid=303) Epoch 16, Step 10, Loss 0.3585
# (launch_and_fit pid=303) Epoch 16, Step 20, Loss 0.1000
# (launch_and_fit pid=303) Epoch 16, Step 30, Loss 0.0639
# (launch_and_fit pid=303) Epoch 16, Step 40, Loss 0.1077
# (launch_and_fit pid=303) Epoch 16, Step 50, Loss 0.1968
# (launch_and_fit pid=303) Epoch 16, Step 60, Loss 0.0231
# (launch_and_fit pid=303) Epoch 16, Step 70, Loss 0.9483
# (launch_and_fit pid=303) Epoch 16, Step 80, Loss 0.0295
# (launch_and_fit pid=303) Epoch 16, Step 90, Loss 0.3842
# (launch_and_fit pid=303) Epoch 16, Step 100, Loss 0.3678
# (launch_and_fit pid=303) Epoch 16, Step 110, Loss 0.4261
# (launch_and_fit pid=303) Epoch 16, Step 120, Loss 0.2083
# (launch_and_fit pid=303) Epoch 16, Step 130, Loss 0.2377
# (launch_and_fit pid=303) Epoch 16, Step 140, Loss 0.1442
# (launch_and_fit pid=303) Epoch 00017: reducing learning rate of group 0 to 1.0000e-04.
# (launch_and_fit pid=303) Epoch 16, Valid Accuracy 83.33%
# (launch_and_fit pid=303) [INFO] Patience 2 remaining
# (launch_and_fit pid=303) Epoch 17, Step 0, Loss 0.1219
# (launch_and_fit pid=303) Epoch 17, Step 10, Loss 0.1319
# (launch_and_fit pid=303) Epoch 17, Step 20, Loss 0.4411
# (launch_and_fit pid=303) Epoch 17, Step 30, Loss 0.1767
# (launch_and_fit pid=303) Epoch 17, Step 40, Loss 0.0680
# (launch_and_fit pid=303) Epoch 17, Step 50, Loss 0.0403
# (launch_and_fit pid=303) Epoch 17, Step 60, Loss 0.3111
# (launch_and_fit pid=303) Epoch 17, Step 70, Loss 0.1075
# (launch_and_fit pid=303) Epoch 17, Step 80, Loss 0.0281
# (launch_and_fit pid=303) Epoch 17, Step 90, Loss 0.1087
# (launch_and_fit pid=303) Epoch 17, Step 100, Loss 0.1789
# (launch_and_fit pid=303) Epoch 17, Step 110, Loss 0.0314
# (launch_and_fit pid=303) Epoch 17, Step 120, Loss 0.2600
# (launch_and_fit pid=303) Epoch 17, Step 130, Loss 0.0483
# (launch_and_fit pid=303) Epoch 17, Step 140, Loss 0.1293
# (launch_and_fit pid=303) Epoch 17, Valid Accuracy 84.92%
# (launch_and_fit pid=303) [INFO] Patience 1 remaining
# (launch_and_fit pid=303) Epoch 18, Step 0, Loss 0.1567
# (launch_and_fit pid=303) Epoch 18, Step 10, Loss 0.4955
# (launch_and_fit pid=303) Epoch 18, Step 20, Loss 0.0731
# (launch_and_fit pid=303) Epoch 18, Step 30, Loss 0.0132
# (launch_and_fit pid=303) Epoch 18, Step 40, Loss 0.0177
# (launch_and_fit pid=303) Epoch 18, Step 50, Loss 0.0333
# (launch_and_fit pid=303) Epoch 18, Step 60, Loss 0.0367
# (launch_and_fit pid=303) Epoch 18, Step 70, Loss 0.4670
# (launch_and_fit pid=303) Epoch 18, Step 80, Loss 0.2492
# (launch_and_fit pid=303) Epoch 18, Step 90, Loss 0.1369
# (launch_and_fit pid=303) Epoch 18, Step 100, Loss 0.0593
# (launch_and_fit pid=303) Epoch 18, Step 110, Loss 0.2751
# (launch_and_fit pid=303) Epoch 18, Step 120, Loss 0.1359
# (launch_and_fit pid=303) Epoch 18, Step 130, Loss 0.0847
# (launch_and_fit pid=303) Epoch 18, Step 140, Loss 0.0370
# (launch_and_fit pid=303) Epoch 18, Valid Accuracy 84.92%
# (launch_and_fit pid=303) [Early Stopping] Epoch 18, Valid Accuracy 84.92%, Valid Loss 0.3632
# (launch_and_fit pid=303) [Client 2] get_parameters
# (launch_and_fit pid=747) [Client 0] fit, config: {}
# (launch_and_fit pid=747) /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# (launch_and_fit pid=747)   warnings.warn(
# (launch_and_fit pid=747) Epoch 0, Step 0, Loss 1.4118
# (launch_and_fit pid=747) Epoch 0, Step 10, Loss 1.2724
# (launch_and_fit pid=747) Epoch 0, Step 20, Loss 0.9881
# (launch_and_fit pid=747) Epoch 0, Step 30, Loss 0.6103
# (launch_and_fit pid=747) Epoch 0, Step 40, Loss 0.9860
# (launch_and_fit pid=747) Epoch 0, Step 50, Loss 0.8725
# (launch_and_fit pid=747) Epoch 0, Step 60, Loss 1.1489
# (launch_and_fit pid=747) Epoch 0, Step 70, Loss 1.4200
# (launch_and_fit pid=747) Epoch 0, Step 80, Loss 1.3774
# (launch_and_fit pid=747) Epoch 0, Step 90, Loss 0.9992
# (launch_and_fit pid=747) Epoch 0, Step 100, Loss 1.0037
# (launch_and_fit pid=747) Epoch 0, Step 110, Loss 0.5229
# (launch_and_fit pid=747) Epoch 0, Step 120, Loss 0.3887
# (launch_and_fit pid=747) Epoch 0, Step 130, Loss 1.1247
# (launch_and_fit pid=747) Epoch 0, Step 140, Loss 0.8148
# (launch_and_fit pid=747) Epoch 0, Valid Accuracy 58.73%
# (launch_and_fit pid=747) Epoch 1, Step 0, Loss 0.6671
# (launch_and_fit pid=747) Epoch 1, Step 10, Loss 0.5963
# (launch_and_fit pid=747) Epoch 1, Step 20, Loss 0.9081
# (launch_and_fit pid=747) Epoch 1, Step 30, Loss 0.8083
# (launch_and_fit pid=747) Epoch 1, Step 40, Loss 1.0138
# (launch_and_fit pid=747) Epoch 1, Step 50, Loss 1.0620
# (launch_and_fit pid=747) Epoch 1, Step 60, Loss 0.6185
# (launch_and_fit pid=747) Epoch 1, Step 70, Loss 0.4598
# (launch_and_fit pid=747) Epoch 1, Step 80, Loss 0.3995
# (launch_and_fit pid=747) Epoch 1, Step 90, Loss 0.8039
# (launch_and_fit pid=747) Epoch 1, Step 100, Loss 0.3662
# (launch_and_fit pid=747) Epoch 1, Step 110, Loss 1.3250
# (launch_and_fit pid=747) Epoch 1, Step 120, Loss 0.3904
# (launch_and_fit pid=747) Epoch 1, Step 130, Loss 0.4194
# (launch_and_fit pid=747) Epoch 1, Step 140, Loss 0.5586
# (launch_and_fit pid=747) Epoch 1, Valid Accuracy 76.19%
# (launch_and_fit pid=747) Epoch 2, Step 0, Loss 0.8449
# (launch_and_fit pid=747) Epoch 2, Step 10, Loss 0.4945
# (launch_and_fit pid=747) Epoch 2, Step 20, Loss 0.7520
# (launch_and_fit pid=747) Epoch 2, Step 30, Loss 0.2241
# (launch_and_fit pid=747) Epoch 2, Step 40, Loss 0.8274
# (launch_and_fit pid=747) Epoch 2, Step 50, Loss 0.5529
# (launch_and_fit pid=747) Epoch 2, Step 60, Loss 0.6169
# (launch_and_fit pid=747) Epoch 2, Step 70, Loss 0.5213
# (launch_and_fit pid=747) Epoch 2, Step 80, Loss 0.7723
# (launch_and_fit pid=747) Epoch 2, Step 90, Loss 0.6427
# (launch_and_fit pid=747) Epoch 2, Step 100, Loss 0.6280
# (launch_and_fit pid=747) Epoch 2, Step 110, Loss 1.0320
# (launch_and_fit pid=747) Epoch 2, Step 120, Loss 0.9049
# (launch_and_fit pid=747) Epoch 2, Step 130, Loss 0.3038
# (launch_and_fit pid=747) Epoch 2, Step 140, Loss 0.5642
# (launch_and_fit pid=747) Epoch 2, Valid Accuracy 81.75%
# (launch_and_fit pid=747) Epoch 3, Step 0, Loss 1.1506
# (launch_and_fit pid=747) Epoch 3, Step 10, Loss 0.5040
# (launch_and_fit pid=747) Epoch 3, Step 20, Loss 0.4755
# (launch_and_fit pid=747) Epoch 3, Step 30, Loss 0.2971
# (launch_and_fit pid=747) Epoch 3, Step 40, Loss 0.5362
# (launch_and_fit pid=747) Epoch 3, Step 50, Loss 0.8552
# (launch_and_fit pid=747) Epoch 3, Step 60, Loss 1.0803
# (launch_and_fit pid=747) Epoch 3, Step 70, Loss 0.3884
# (launch_and_fit pid=747) Epoch 3, Step 80, Loss 0.5627
# (launch_and_fit pid=747) Epoch 3, Step 90, Loss 0.6659
# (launch_and_fit pid=747) Epoch 3, Step 100, Loss 0.3410
# (launch_and_fit pid=747) Epoch 3, Step 110, Loss 0.5929
# (launch_and_fit pid=747) Epoch 3, Step 120, Loss 0.2957
# (launch_and_fit pid=747) Epoch 3, Step 130, Loss 0.6852
# (launch_and_fit pid=747) Epoch 3, Step 140, Loss 0.3588
# (launch_and_fit pid=747) Epoch 3, Valid Accuracy 85.71%
# (launch_and_fit pid=747) Epoch 4, Step 0, Loss 0.1363
# (launch_and_fit pid=747) Epoch 4, Step 10, Loss 1.2832
# (launch_and_fit pid=747) Epoch 4, Step 20, Loss 0.7454
# (launch_and_fit pid=747) Epoch 4, Step 30, Loss 0.3392
# (launch_and_fit pid=747) Epoch 4, Step 40, Loss 0.5463
# (launch_and_fit pid=747) Epoch 4, Step 50, Loss 0.5464
# (launch_and_fit pid=747) Epoch 4, Step 60, Loss 0.3007
# (launch_and_fit pid=747) Epoch 4, Step 70, Loss 0.2677
# (launch_and_fit pid=747) Epoch 4, Step 80, Loss 0.5204
# (launch_and_fit pid=747) Epoch 4, Step 90, Loss 0.3182
# (launch_and_fit pid=747) Epoch 4, Step 100, Loss 0.5627
# (launch_and_fit pid=747) Epoch 4, Step 110, Loss 0.2987
# (launch_and_fit pid=747) Epoch 4, Step 120, Loss 0.2788
# (launch_and_fit pid=747) Epoch 4, Step 130, Loss 0.3415
# (launch_and_fit pid=747) Epoch 4, Step 140, Loss 0.6951
# (launch_and_fit pid=747) Epoch 4, Valid Accuracy 75.40%
# (launch_and_fit pid=747) [INFO] Patience 5 remaining
# (launch_and_fit pid=747) Epoch 5, Step 0, Loss 0.2647
# (launch_and_fit pid=747) Epoch 5, Step 10, Loss 0.8027
# (launch_and_fit pid=747) Epoch 5, Step 20, Loss 0.6771
# (launch_and_fit pid=747) Epoch 5, Step 30, Loss 0.3412
# (launch_and_fit pid=747) Epoch 5, Step 40, Loss 0.1992
# (launch_and_fit pid=747) Epoch 5, Step 50, Loss 0.8282
# (launch_and_fit pid=747) Epoch 5, Step 60, Loss 0.2421
# (launch_and_fit pid=747) Epoch 5, Step 70, Loss 0.8395
# (launch_and_fit pid=747) Epoch 5, Step 80, Loss 0.6744
# (launch_and_fit pid=747) Epoch 5, Step 90, Loss 0.6283
# (launch_and_fit pid=747) Epoch 5, Step 100, Loss 0.6427
# (launch_and_fit pid=747) Epoch 5, Step 110, Loss 0.1731
# (launch_and_fit pid=747) Epoch 5, Step 120, Loss 0.6836
# (launch_and_fit pid=747) Epoch 5, Step 130, Loss 0.2303
# (launch_and_fit pid=747) Epoch 5, Step 140, Loss 0.1869
# (launch_and_fit pid=747) Epoch 5, Valid Accuracy 88.10%
# (launch_and_fit pid=747) Epoch 6, Step 0, Loss 0.1534
# (launch_and_fit pid=747) Epoch 6, Step 10, Loss 0.4985
# (launch_and_fit pid=747) Epoch 6, Step 20, Loss 0.4565
# (launch_and_fit pid=747) Epoch 6, Step 30, Loss 0.6629
# (launch_and_fit pid=747) Epoch 6, Step 40, Loss 0.3257
# (launch_and_fit pid=747) Epoch 6, Step 50, Loss 0.6260
# (launch_and_fit pid=747) Epoch 6, Step 60, Loss 0.4104
# (launch_and_fit pid=747) Epoch 6, Step 70, Loss 0.2058
# (launch_and_fit pid=747) Epoch 6, Step 80, Loss 0.5599
# (launch_and_fit pid=747) Epoch 6, Step 90, Loss 0.4783
# (launch_and_fit pid=747) Epoch 6, Step 100, Loss 0.1415
# (launch_and_fit pid=747) Epoch 6, Step 110, Loss 0.5224
# (launch_and_fit pid=747) Epoch 6, Step 120, Loss 0.4860
# (launch_and_fit pid=747) Epoch 6, Step 130, Loss 0.4954
# (launch_and_fit pid=747) Epoch 6, Step 140, Loss 0.6606
# (launch_and_fit pid=747) Epoch 6, Valid Accuracy 84.92%
# (launch_and_fit pid=747) [INFO] Patience 5 remaining
# (launch_and_fit pid=747) Epoch 7, Step 0, Loss 0.9857
# (launch_and_fit pid=747) Epoch 7, Step 10, Loss 0.3506
# (launch_and_fit pid=747) Epoch 7, Step 20, Loss 0.6322
# (launch_and_fit pid=747) Epoch 7, Step 30, Loss 0.2022
# (launch_and_fit pid=747) Epoch 7, Step 40, Loss 0.9839
# (launch_and_fit pid=747) Epoch 7, Step 50, Loss 0.3057
# (launch_and_fit pid=747) Epoch 7, Step 60, Loss 0.2781
# (launch_and_fit pid=747) Epoch 7, Step 70, Loss 0.4082
# (launch_and_fit pid=747) Epoch 7, Step 80, Loss 0.4369
# (launch_and_fit pid=747) Epoch 7, Step 90, Loss 0.4117
# (launch_and_fit pid=747) Epoch 7, Step 100, Loss 0.1083
# (launch_and_fit pid=747) Epoch 7, Step 110, Loss 0.3204
# (launch_and_fit pid=747) Epoch 7, Step 120, Loss 0.7265
# (launch_and_fit pid=747) Epoch 7, Step 130, Loss 0.1700
# (launch_and_fit pid=747) Epoch 7, Step 140, Loss 0.2261
# (launch_and_fit pid=747) Epoch 7, Valid Accuracy 87.30%
# (launch_and_fit pid=747) Epoch 8, Step 0, Loss 0.6091
# (launch_and_fit pid=747) Epoch 8, Step 10, Loss 0.3176
# (launch_and_fit pid=747) Epoch 8, Step 20, Loss 0.6530
# (launch_and_fit pid=747) Epoch 8, Step 30, Loss 0.3186
# (launch_and_fit pid=747) Epoch 8, Step 40, Loss 0.3012
# (launch_and_fit pid=747) Epoch 8, Step 50, Loss 0.3726
# (launch_and_fit pid=747) Epoch 8, Step 60, Loss 0.2414
# (launch_and_fit pid=747) Epoch 8, Step 70, Loss 0.8633
# (launch_and_fit pid=747) Epoch 8, Step 80, Loss 0.6480
# (launch_and_fit pid=747) Epoch 8, Step 90, Loss 0.2806
# (launch_and_fit pid=747) Epoch 8, Step 100, Loss 0.5254
# (launch_and_fit pid=747) Epoch 8, Step 110, Loss 0.1515
# (launch_and_fit pid=747) Epoch 8, Step 120, Loss 0.5307
# (launch_and_fit pid=747) Epoch 8, Step 130, Loss 0.1907
# (launch_and_fit pid=747) Epoch 8, Step 140, Loss 0.5451
# (launch_and_fit pid=747) Epoch 8, Valid Accuracy 86.51%
# (launch_and_fit pid=747) [INFO] Patience 5 remaining
# (launch_and_fit pid=747) Epoch 9, Step 0, Loss 0.4926
# (launch_and_fit pid=747) Epoch 9, Step 10, Loss 0.3789
# (launch_and_fit pid=747) Epoch 9, Step 20, Loss 0.3150
# (launch_and_fit pid=747) Epoch 9, Step 30, Loss 0.4484
# (launch_and_fit pid=747) Epoch 9, Step 40, Loss 0.6637
# (launch_and_fit pid=747) Epoch 9, Step 50, Loss 0.1471
# (launch_and_fit pid=747) Epoch 9, Step 60, Loss 0.1758
# (launch_and_fit pid=747) Epoch 9, Step 70, Loss 0.4918
# (launch_and_fit pid=747) Epoch 9, Step 80, Loss 1.2253
# (launch_and_fit pid=747) Epoch 9, Step 90, Loss 0.7174
# (launch_and_fit pid=747) Epoch 9, Step 100, Loss 0.4424
# (launch_and_fit pid=747) Epoch 9, Step 110, Loss 0.7705
# (launch_and_fit pid=747) Epoch 9, Step 120, Loss 0.1891
# (launch_and_fit pid=747) Epoch 9, Step 130, Loss 0.4716
# (launch_and_fit pid=747) Epoch 9, Step 140, Loss 0.1085
# (launch_and_fit pid=747) Epoch 9, Valid Accuracy 91.27%
# (launch_and_fit pid=747) Epoch 10, Step 0, Loss 0.1117
# (launch_and_fit pid=747) Epoch 10, Step 10, Loss 0.9978
# (launch_and_fit pid=747) Epoch 10, Step 20, Loss 0.2901
# (launch_and_fit pid=747) Epoch 10, Step 30, Loss 0.5955
# (launch_and_fit pid=747) Epoch 10, Step 40, Loss 0.1176
# (launch_and_fit pid=747) Epoch 10, Step 50, Loss 0.2729
# (launch_and_fit pid=747) Epoch 10, Step 60, Loss 0.5044
# (launch_and_fit pid=747) Epoch 10, Step 70, Loss 0.5379
# (launch_and_fit pid=747) Epoch 10, Step 80, Loss 0.5671
# (launch_and_fit pid=747) Epoch 10, Step 90, Loss 1.1894
# (launch_and_fit pid=747) Epoch 10, Step 100, Loss 0.1604
# (launch_and_fit pid=747) Epoch 10, Step 110, Loss 0.3235
# (launch_and_fit pid=747) Epoch 10, Step 120, Loss 0.2258
# (launch_and_fit pid=747) Epoch 10, Step 130, Loss 0.4696
# (launch_and_fit pid=747) Epoch 10, Step 140, Loss 0.2841
# (launch_and_fit pid=747) Epoch 10, Valid Accuracy 79.37%
# (launch_and_fit pid=747) [INFO] Patience 5 remaining
# (launch_and_fit pid=747) Epoch 11, Step 0, Loss 0.1195
# (launch_and_fit pid=747) Epoch 11, Step 10, Loss 0.0309
# (launch_and_fit pid=747) Epoch 11, Step 20, Loss 0.2068
# (launch_and_fit pid=747) Epoch 11, Step 30, Loss 0.1075
# (launch_and_fit pid=747) Epoch 11, Step 40, Loss 0.7544
# (launch_and_fit pid=747) Epoch 11, Step 50, Loss 0.1854
# (launch_and_fit pid=747) Epoch 11, Step 60, Loss 0.5362
# (launch_and_fit pid=747) Epoch 11, Step 70, Loss 0.4172
# (launch_and_fit pid=747) Epoch 11, Step 80, Loss 0.1152
# (launch_and_fit pid=747) Epoch 11, Step 90, Loss 0.0858
# (launch_and_fit pid=747) Epoch 11, Step 100, Loss 0.0989
# (launch_and_fit pid=747) Epoch 11, Step 110, Loss 0.0121
# (launch_and_fit pid=747) Epoch 11, Step 120, Loss 0.0520
# (launch_and_fit pid=747) Epoch 11, Step 130, Loss 0.1962
# (launch_and_fit pid=747) Epoch 11, Step 140, Loss 0.4787
# (launch_and_fit pid=747) Epoch 11, Valid Accuracy 80.95%
# (launch_and_fit pid=747) [INFO] Patience 4 remaining
# (launch_and_fit pid=747) Epoch 12, Step 0, Loss 0.1123
# (launch_and_fit pid=747) Epoch 12, Step 10, Loss 0.1067
# (launch_and_fit pid=747) Epoch 12, Step 20, Loss 0.2686
# (launch_and_fit pid=747) Epoch 12, Step 30, Loss 0.1797
# (launch_and_fit pid=747) Epoch 12, Step 40, Loss 0.3617
# (launch_and_fit pid=747) Epoch 12, Step 50, Loss 0.0629
# (launch_and_fit pid=747) Epoch 12, Step 60, Loss 0.2575
# (launch_and_fit pid=747) Epoch 12, Step 70, Loss 0.2653
# (launch_and_fit pid=747) Epoch 12, Step 80, Loss 0.0406
# (launch_and_fit pid=747) Epoch 12, Step 90, Loss 0.1668
# (launch_and_fit pid=747) Epoch 12, Step 100, Loss 0.3865
# (launch_and_fit pid=747) Epoch 12, Step 110, Loss 0.0454
# (launch_and_fit pid=747) Epoch 12, Step 120, Loss 0.2618
# (launch_and_fit pid=747) Epoch 12, Step 130, Loss 0.3257
# (launch_and_fit pid=747) Epoch 12, Step 140, Loss 0.6361
# (launch_and_fit pid=747) Epoch 12, Valid Accuracy 91.27%
# (launch_and_fit pid=747) Epoch 13, Step 0, Loss 0.5752
# (launch_and_fit pid=747) Epoch 13, Step 10, Loss 0.3116
# (launch_and_fit pid=747) Epoch 13, Step 20, Loss 0.3395
# (launch_and_fit pid=747) Epoch 13, Step 30, Loss 0.3142
# (launch_and_fit pid=747) Epoch 13, Step 40, Loss 0.0871
# (launch_and_fit pid=747) Epoch 13, Step 50, Loss 0.1168
# (launch_and_fit pid=747) Epoch 13, Step 60, Loss 0.0680
# (launch_and_fit pid=747) Epoch 13, Step 70, Loss 0.0646
# (launch_and_fit pid=747) Epoch 13, Step 80, Loss 0.2070
# (launch_and_fit pid=747) Epoch 13, Step 90, Loss 0.1611
# (launch_and_fit pid=747) Epoch 13, Step 100, Loss 0.0061
# (launch_and_fit pid=747) Epoch 13, Step 110, Loss 0.4664
# (launch_and_fit pid=747) Epoch 13, Step 120, Loss 0.5741
# (launch_and_fit pid=747) Epoch 13, Step 130, Loss 0.0104
# (launch_and_fit pid=747) Epoch 13, Step 140, Loss 0.8073
# (launch_and_fit pid=747) Epoch 13, Valid Accuracy 89.68%
# (launch_and_fit pid=747) [INFO] Patience 5 remaining
# (launch_and_fit pid=747) Epoch 14, Step 0, Loss 0.1905
# (launch_and_fit pid=747) Epoch 14, Step 10, Loss 0.6177
# (launch_and_fit pid=747) Epoch 14, Step 20, Loss 0.6681
# (launch_and_fit pid=747) Epoch 14, Step 30, Loss 0.5848
# (launch_and_fit pid=747) Epoch 14, Step 40, Loss 0.0091
# (launch_and_fit pid=747) Epoch 14, Step 50, Loss 0.0833
# (launch_and_fit pid=747) Epoch 14, Step 60, Loss 0.0577
# (launch_and_fit pid=747) Epoch 14, Step 70, Loss 0.0688
# (launch_and_fit pid=747) Epoch 14, Step 80, Loss 0.0406
# (launch_and_fit pid=747) Epoch 14, Step 90, Loss 0.1757
# (launch_and_fit pid=747) Epoch 14, Step 100, Loss 0.3362
# (launch_and_fit pid=747) Epoch 14, Step 110, Loss 0.6062
# (launch_and_fit pid=747) Epoch 14, Step 120, Loss 0.3696
# (launch_and_fit pid=747) Epoch 14, Step 130, Loss 0.3747
# (launch_and_fit pid=747) Epoch 14, Step 140, Loss 0.1077
# (launch_and_fit pid=747) Epoch 14, Valid Accuracy 92.06%
# (launch_and_fit pid=747) Epoch 15, Step 0, Loss 0.1056
# (launch_and_fit pid=747) Epoch 15, Step 10, Loss 0.1461
# (launch_and_fit pid=747) Epoch 15, Step 20, Loss 0.0128
# (launch_and_fit pid=747) Epoch 15, Step 30, Loss 0.1845
# (launch_and_fit pid=747) Epoch 15, Step 40, Loss 0.0216
# (launch_and_fit pid=747) Epoch 15, Step 50, Loss 0.7057
# (launch_and_fit pid=747) Epoch 15, Step 60, Loss 0.2822
# (launch_and_fit pid=747) Epoch 15, Step 70, Loss 0.0526
# (launch_and_fit pid=747) Epoch 15, Step 80, Loss 0.7537
# (launch_and_fit pid=747) Epoch 15, Step 90, Loss 0.0829
# (launch_and_fit pid=747) Epoch 15, Step 100, Loss 0.5963
# (launch_and_fit pid=747) Epoch 15, Step 110, Loss 0.0626
# (launch_and_fit pid=747) Epoch 15, Step 120, Loss 0.0296
# (launch_and_fit pid=747) Epoch 15, Step 130, Loss 0.0384
# (launch_and_fit pid=747) Epoch 15, Step 140, Loss 0.4155
# (launch_and_fit pid=747) Epoch 15, Valid Accuracy 90.48%
# (launch_and_fit pid=747) [INFO] Patience 5 remaining
# (launch_and_fit pid=747) Epoch 16, Step 0, Loss 0.0182
# (launch_and_fit pid=747) Epoch 16, Step 10, Loss 0.0076
# (launch_and_fit pid=747) Epoch 16, Step 20, Loss 0.3758
# (launch_and_fit pid=747) Epoch 16, Step 30, Loss 0.0227
# (launch_and_fit pid=747) Epoch 16, Step 40, Loss 0.0412
# (launch_and_fit pid=747) Epoch 16, Step 50, Loss 0.1144
# (launch_and_fit pid=747) Epoch 16, Step 60, Loss 0.2152
# (launch_and_fit pid=747) Epoch 16, Step 70, Loss 0.5778
# (launch_and_fit pid=747) Epoch 16, Step 80, Loss 0.1262
# (launch_and_fit pid=747) Epoch 16, Step 90, Loss 0.2503
# (launch_and_fit pid=747) Epoch 16, Step 100, Loss 0.6593
# (launch_and_fit pid=747) Epoch 16, Step 110, Loss 0.0217
# (launch_and_fit pid=747) Epoch 16, Step 120, Loss 0.2398
# (launch_and_fit pid=747) Epoch 16, Step 130, Loss 0.2725
# (launch_and_fit pid=747) Epoch 16, Step 140, Loss 0.1377
# (launch_and_fit pid=747) Epoch 16, Valid Accuracy 87.30%
# (launch_and_fit pid=747) [INFO] Patience 4 remaining
# (launch_and_fit pid=747) Epoch 17, Step 0, Loss 0.0337
# (launch_and_fit pid=747) Epoch 17, Step 10, Loss 0.1055
# (launch_and_fit pid=747) Epoch 17, Step 20, Loss 0.0520
# (launch_and_fit pid=747) Epoch 17, Step 30, Loss 0.0075
# (launch_and_fit pid=747) Epoch 17, Step 40, Loss 0.3204
# (launch_and_fit pid=747) Epoch 17, Step 50, Loss 0.4863
# (launch_and_fit pid=747) Epoch 17, Step 60, Loss 0.4751
# (launch_and_fit pid=747) Epoch 17, Step 70, Loss 0.0205
# (launch_and_fit pid=747) Epoch 17, Step 80, Loss 0.0476
# (launch_and_fit pid=747) Epoch 17, Step 90, Loss 0.2229
# (launch_and_fit pid=747) Epoch 17, Step 100, Loss 0.0792
# (launch_and_fit pid=747) Epoch 17, Step 110, Loss 0.3139
# (launch_and_fit pid=747) Epoch 17, Step 120, Loss 0.3299
# (launch_and_fit pid=747) Epoch 17, Step 130, Loss 0.1173
# (launch_and_fit pid=747) Epoch 17, Step 140, Loss 0.0551
# (launch_and_fit pid=747) Epoch 17, Valid Accuracy 92.86%
# (launch_and_fit pid=747) [INFO] Patience 3 remaining
# (launch_and_fit pid=747) Epoch 18, Step 0, Loss 0.0340
# (launch_and_fit pid=747) Epoch 18, Step 10, Loss 0.4834
# (launch_and_fit pid=747) Epoch 18, Step 20, Loss 0.1335
# (launch_and_fit pid=747) Epoch 18, Step 30, Loss 0.0283
# (launch_and_fit pid=747) Epoch 18, Step 40, Loss 0.0399
# (launch_and_fit pid=747) Epoch 18, Step 50, Loss 0.0426
# (launch_and_fit pid=747) Epoch 18, Step 60, Loss 0.0397
# (launch_and_fit pid=747) Epoch 18, Step 70, Loss 0.0058
# (launch_and_fit pid=747) Epoch 18, Step 80, Loss 0.1044
# (launch_and_fit pid=747) Epoch 18, Step 90, Loss 0.0526
# (launch_and_fit pid=747) Epoch 18, Step 100, Loss 0.1415
# (launch_and_fit pid=747) Epoch 18, Step 110, Loss 0.1749
# (launch_and_fit pid=747) Epoch 18, Step 120, Loss 0.3719
# (launch_and_fit pid=747) Epoch 18, Step 130, Loss 0.0262
# (launch_and_fit pid=747) Epoch 18, Step 140, Loss 0.1799
# (launch_and_fit pid=747) Epoch 00019: reducing learning rate of group 0 to 1.0000e-04.
# (launch_and_fit pid=747) Epoch 18, Valid Accuracy 88.10%
# (launch_and_fit pid=747) [INFO] Patience 2 remaining
# (launch_and_fit pid=747) Epoch 19, Step 0, Loss 0.0934
# (launch_and_fit pid=747) Epoch 19, Step 10, Loss 0.2388
# (launch_and_fit pid=747) Epoch 19, Step 20, Loss 0.0416
# (launch_and_fit pid=747) Epoch 19, Step 30, Loss 0.2410
# (launch_and_fit pid=747) Epoch 19, Step 40, Loss 0.0156
# (launch_and_fit pid=747) Epoch 19, Step 50, Loss 0.1615
# (launch_and_fit pid=747) Epoch 19, Step 60, Loss 0.0262
# (launch_and_fit pid=747) Epoch 19, Step 70, Loss 0.0706
# (launch_and_fit pid=747) Epoch 19, Step 80, Loss 0.1894
# (launch_and_fit pid=747) Epoch 19, Step 90, Loss 0.5213
# (launch_and_fit pid=747) Epoch 19, Step 100, Loss 0.4434
# (launch_and_fit pid=747) Epoch 19, Step 110, Loss 0.0120
# (launch_and_fit pid=747) Epoch 19, Step 120, Loss 0.8721
# (launch_and_fit pid=747) Epoch 19, Step 130, Loss 0.0239
# (launch_and_fit pid=747) Epoch 19, Step 140, Loss 0.2186
# (launch_and_fit pid=747) Epoch 19, Valid Accuracy 92.86%
# (launch_and_fit pid=747) [INFO] Patience 1 remaining
# (launch_and_fit pid=747) [Client 0] get_parameters
# DEBUG flower 2023-12-12 00:48:52,291 | server.py:277 | fit_round received 2 results and 0 failures
# INFO flower 2023-12-12 00:49:05,188 | server.py:158 | fit progress: (1, nan, {'val_accuracy': 0.25396825396825395, 'test_accuracy': 0.27014218009478674}, 1108.838047481)
# INFO flower 2023-12-12 00:49:05,189 | server.py:209 | evaluate_round: no clients selected, cancel
# DEBUG flower 2023-12-12 00:49:05,190 | server.py:265 | fit_round: strategy sampled 2 clients (out of 3)
# (launch_and_fit pid=1223) [Client 1] fit, config: {}
# (launch_and_fit pid=1223) /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# (launch_and_fit pid=1223)   warnings.warn(
# (launch_and_fit pid=1223) Epoch 0, Step 0, Loss 2.6489
# (launch_and_fit pid=1223) Epoch 0, Step 10, Loss 0.6542
# (launch_and_fit pid=1223) Epoch 0, Step 20, Loss 0.3202
# (launch_and_fit pid=1223) Epoch 0, Step 30, Loss 0.4631
# (launch_and_fit pid=1223) Epoch 0, Step 40, Loss 0.8318
# (launch_and_fit pid=1223) Epoch 0, Step 50, Loss 0.6734
# (launch_and_fit pid=1223) Epoch 0, Step 60, Loss 0.5426
# (launch_and_fit pid=1223) Epoch 0, Step 70, Loss 0.4235
# (launch_and_fit pid=1223) Epoch 0, Step 80, Loss 0.3776
# (launch_and_fit pid=1223) Epoch 0, Step 90, Loss 0.0661
# (launch_and_fit pid=1223) Epoch 0, Step 100, Loss 0.7649
# (launch_and_fit pid=1223) Epoch 0, Step 110, Loss 0.5396
# (launch_and_fit pid=1223) Epoch 0, Step 120, Loss 0.3305
# (launch_and_fit pid=1223) Epoch 0, Step 130, Loss 0.3918
# (launch_and_fit pid=1223) Epoch 0, Step 140, Loss 0.1676
# (launch_and_fit pid=1223) Epoch 0, Valid Accuracy 83.33%
# (launch_and_fit pid=1223) Epoch 1, Step 0, Loss 0.0425
# (launch_and_fit pid=1223) Epoch 1, Step 10, Loss 0.3743
# (launch_and_fit pid=1223) Epoch 1, Step 20, Loss 0.5506
# (launch_and_fit pid=1223) Epoch 1, Step 30, Loss 0.3140
# (launch_and_fit pid=1223) Epoch 1, Step 40, Loss 0.5406
# (launch_and_fit pid=1223) Epoch 1, Step 50, Loss 0.0789
# (launch_and_fit pid=1223) Epoch 1, Step 60, Loss 0.3739
# (launch_and_fit pid=1223) Epoch 1, Step 70, Loss 1.3729
# (launch_and_fit pid=1223) Epoch 1, Step 80, Loss 0.4164
# (launch_and_fit pid=1223) Epoch 1, Step 90, Loss 0.1667
# (launch_and_fit pid=1223) Epoch 1, Step 100, Loss 0.4497
# (launch_and_fit pid=1223) Epoch 1, Step 110, Loss 0.8258
# (launch_and_fit pid=1223) Epoch 1, Step 120, Loss 0.0542
# (launch_and_fit pid=1223) Epoch 1, Step 130, Loss 0.0500
# (launch_and_fit pid=1223) Epoch 1, Step 140, Loss 0.6472
# (launch_and_fit pid=1223) Epoch 1, Valid Accuracy 85.71%
# (launch_and_fit pid=1223) Epoch 2, Step 0, Loss 0.0480
# (launch_and_fit pid=1223) Epoch 2, Step 10, Loss 0.1125
# (launch_and_fit pid=1223) Epoch 2, Step 20, Loss 0.0172
# (launch_and_fit pid=1223) Epoch 2, Step 30, Loss 0.0789
# (launch_and_fit pid=1223) Epoch 2, Step 40, Loss 0.0185
# (launch_and_fit pid=1223) Epoch 2, Step 50, Loss 0.1521
# (launch_and_fit pid=1223) Epoch 2, Step 60, Loss 0.0444
# (launch_and_fit pid=1223) Epoch 2, Step 70, Loss 0.0812
# (launch_and_fit pid=1223) Epoch 2, Step 80, Loss 0.1326
# (launch_and_fit pid=1223) Epoch 2, Step 90, Loss 0.0719
# (launch_and_fit pid=1223) Epoch 2, Step 100, Loss 0.0766
# (launch_and_fit pid=1223) Epoch 2, Step 110, Loss 0.0305
# (launch_and_fit pid=1223) Epoch 2, Step 120, Loss 0.1014
# (launch_and_fit pid=1223) Epoch 2, Step 130, Loss 0.7710
# (launch_and_fit pid=1223) Epoch 2, Step 140, Loss 0.7660
# (launch_and_fit pid=1223) Epoch 2, Valid Accuracy 85.71%
# (launch_and_fit pid=1223) [INFO] Patience 5 remaining
# (launch_and_fit pid=1223) Epoch 3, Step 0, Loss 0.3012
# (launch_and_fit pid=1223) Epoch 3, Step 10, Loss 0.1849
# (launch_and_fit pid=1223) Epoch 3, Step 20, Loss 0.9536
# (launch_and_fit pid=1223) Epoch 3, Step 30, Loss 0.4866
# (launch_and_fit pid=1223) Epoch 3, Step 40, Loss 1.1130
# (launch_and_fit pid=1223) Epoch 3, Step 50, Loss 0.3376
# (launch_and_fit pid=1223) Epoch 3, Step 60, Loss 0.1076
# (launch_and_fit pid=1223) Epoch 3, Step 70, Loss 0.0897
# (launch_and_fit pid=1223) Epoch 3, Step 80, Loss 0.0196
# (launch_and_fit pid=1223) Epoch 3, Step 90, Loss 0.3848
# (launch_and_fit pid=1223) Epoch 3, Step 100, Loss 0.3503
# (launch_and_fit pid=1223) Epoch 3, Step 110, Loss 0.3925
# (launch_and_fit pid=1223) Epoch 3, Step 120, Loss 0.0333
# (launch_and_fit pid=1223) Epoch 3, Step 130, Loss 0.1583
# (launch_and_fit pid=1223) Epoch 3, Step 140, Loss 0.1173
# (launch_and_fit pid=1223) Epoch 3, Valid Accuracy 88.89%
# (launch_and_fit pid=1223) [INFO] Patience 4 remaining
# (launch_and_fit pid=1223) Epoch 4, Step 0, Loss 0.2240
# (launch_and_fit pid=1223) Epoch 4, Step 10, Loss 0.1073
# (launch_and_fit pid=1223) Epoch 4, Step 20, Loss 0.1226
# (launch_and_fit pid=1223) Epoch 4, Step 30, Loss 0.3009
# (launch_and_fit pid=1223) Epoch 4, Step 40, Loss 0.1668
# (launch_and_fit pid=1223) Epoch 4, Step 50, Loss 0.4205
# (launch_and_fit pid=1223) Epoch 4, Step 60, Loss 0.1099
# (launch_and_fit pid=1223) Epoch 4, Step 70, Loss 0.1349
# (launch_and_fit pid=1223) Epoch 4, Step 80, Loss 0.2408
# (launch_and_fit pid=1223) Epoch 4, Step 90, Loss 0.1559
# (launch_and_fit pid=1223) Epoch 4, Step 100, Loss 0.2482
# (launch_and_fit pid=1223) Epoch 4, Step 110, Loss 0.0721
# (launch_and_fit pid=1223) Epoch 4, Step 120, Loss 0.1086
# (launch_and_fit pid=1223) Epoch 4, Step 130, Loss 0.0282
# (launch_and_fit pid=1223) Epoch 4, Step 140, Loss 0.1837
# (launch_and_fit pid=1223) Epoch 4, Valid Accuracy 89.68%
# (launch_and_fit pid=1223) Epoch 5, Step 0, Loss 0.3552
# (launch_and_fit pid=1223) Epoch 5, Step 10, Loss 0.3735
# (launch_and_fit pid=1223) Epoch 5, Step 20, Loss 0.0216
# (launch_and_fit pid=1223) Epoch 5, Step 30, Loss 0.2290
# (launch_and_fit pid=1223) Epoch 5, Step 40, Loss 0.5184
# (launch_and_fit pid=1223) Epoch 5, Step 50, Loss 0.0978
# (launch_and_fit pid=1223) Epoch 5, Step 60, Loss 0.1245
# (launch_and_fit pid=1223) Epoch 5, Step 70, Loss 0.1303
# (launch_and_fit pid=1223) Epoch 5, Step 80, Loss 0.0408
# (launch_and_fit pid=1223) Epoch 5, Step 90, Loss 0.1256
# (launch_and_fit pid=1223) Epoch 5, Step 100, Loss 0.0919
# (launch_and_fit pid=1223) Epoch 5, Step 110, Loss 0.1366
# (launch_and_fit pid=1223) Epoch 5, Step 120, Loss 0.0163
# (launch_and_fit pid=1223) Epoch 5, Step 130, Loss 0.2149
# (launch_and_fit pid=1223) Epoch 5, Step 140, Loss 0.0109
# (launch_and_fit pid=1223) Epoch 5, Valid Accuracy 88.10%
# (launch_and_fit pid=1223) [INFO] Patience 5 remaining
# (launch_and_fit pid=1223) Epoch 6, Step 0, Loss 0.0725
# (launch_and_fit pid=1223) Epoch 6, Step 10, Loss 0.0931
# (launch_and_fit pid=1223) Epoch 6, Step 20, Loss 0.2200
# (launch_and_fit pid=1223) Epoch 6, Step 30, Loss 0.1778
# (launch_and_fit pid=1223) Epoch 6, Step 40, Loss 0.0673
# (launch_and_fit pid=1223) Epoch 6, Step 50, Loss 0.5978
# (launch_and_fit pid=1223) Epoch 6, Step 60, Loss 0.1742
# (launch_and_fit pid=1223) Epoch 6, Step 70, Loss 0.4303
# (launch_and_fit pid=1223) Epoch 6, Step 80, Loss 0.0750
# (launch_and_fit pid=1223) Epoch 6, Step 90, Loss 0.3510
# (launch_and_fit pid=1223) Epoch 6, Step 100, Loss 0.7044
# (launch_and_fit pid=1223) Epoch 6, Step 110, Loss 0.1560
# (launch_and_fit pid=1223) Epoch 6, Step 120, Loss 0.2111
# (launch_and_fit pid=1223) Epoch 6, Step 130, Loss 0.3060
# (launch_and_fit pid=1223) Epoch 6, Step 140, Loss 0.0993
# (launch_and_fit pid=1223) Epoch 6, Valid Accuracy 82.54%
# (launch_and_fit pid=1223) [INFO] Patience 4 remaining
# (launch_and_fit pid=1223) Epoch 7, Step 0, Loss 0.2737
# (launch_and_fit pid=1223) Epoch 7, Step 10, Loss 0.0039
# (launch_and_fit pid=1223) Epoch 7, Step 20, Loss 0.0478
# (launch_and_fit pid=1223) Epoch 7, Step 30, Loss 0.0375
# (launch_and_fit pid=1223) Epoch 7, Step 40, Loss 0.3802
# (launch_and_fit pid=1223) Epoch 7, Step 50, Loss 0.0709
# (launch_and_fit pid=1223) Epoch 7, Step 60, Loss 0.0775
# (launch_and_fit pid=1223) Epoch 7, Step 70, Loss 0.3231
# (launch_and_fit pid=1223) Epoch 7, Step 80, Loss 0.3174
# ...
# (launch_and_fit pid=6127) Epoch 2, Step 0, Loss 0.0877
# (launch_and_fit pid=6127) Epoch 2, Step 10, Loss 0.0157
# (launch_and_fit pid=6127) Epoch 2, Step 20, Loss 0.0049
# (launch_and_fit pid=6127) Epoch 2, Step 30, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 2, Step 40, Loss 0.0228
# (launch_and_fit pid=6127) Epoch 2, Step 50, Loss 0.0037
# (launch_and_fit pid=6127) Epoch 2, Step 60, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 2, Step 70, Loss 0.0014
# (launch_and_fit pid=6127) Epoch 2, Step 80, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 2, Step 90, Loss 0.0003
# (launch_and_fit pid=6127) Epoch 2, Step 100, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 2, Step 110, Loss 0.0009
# (launch_and_fit pid=6127) Epoch 2, Step 120, Loss 0.5568
# (launch_and_fit pid=6127) Epoch 2, Step 130, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 2, Step 140, Loss 0.0030
# (launch_and_fit pid=6127) Epoch 2, Valid Accuracy 90.48%
# (launch_and_fit pid=6127) [INFO] Patience 4 remaining
# (launch_and_fit pid=6127) Epoch 3, Step 0, Loss 0.0796
# (launch_and_fit pid=6127) Epoch 3, Step 10, Loss 0.0029
# (launch_and_fit pid=6127) Epoch 3, Step 20, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 3, Step 30, Loss 0.3200
# (launch_and_fit pid=6127) Epoch 3, Step 40, Loss 0.0010
# (launch_and_fit pid=6127) Epoch 3, Step 50, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 3, Step 60, Loss 0.0016
# (launch_and_fit pid=6127) Epoch 3, Step 70, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 3, Step 80, Loss 0.0025
# (launch_and_fit pid=6127) Epoch 3, Step 90, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 3, Step 100, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 3, Step 110, Loss 0.0003
# (launch_and_fit pid=6127) Epoch 3, Step 120, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 3, Step 130, Loss 0.0346
# (launch_and_fit pid=6127) Epoch 3, Step 140, Loss 0.0307
# (launch_and_fit pid=6127) Epoch 3, Valid Accuracy 92.06%
# (launch_and_fit pid=6127) Epoch 4, Step 0, Loss 0.0002
# (launch_and_fit pid=6127) Epoch 4, Step 10, Loss 0.3122
# (launch_and_fit pid=6127) Epoch 4, Step 20, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 4, Step 30, Loss 0.0164
# (launch_and_fit pid=6127) Epoch 4, Step 40, Loss 0.0111
# (launch_and_fit pid=6127) Epoch 4, Step 50, Loss 0.1513
# (launch_and_fit pid=6127) Epoch 4, Step 60, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 4, Step 70, Loss 0.0024
# (launch_and_fit pid=6127) Epoch 4, Step 80, Loss 0.0005
# (launch_and_fit pid=6127) Epoch 4, Step 90, Loss 0.0077
# (launch_and_fit pid=6127) Epoch 4, Step 100, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 4, Step 110, Loss 0.2281
# (launch_and_fit pid=6127) Epoch 4, Step 120, Loss 0.0019
# (launch_and_fit pid=6127) Epoch 4, Step 130, Loss 0.0002
# (launch_and_fit pid=6127) Epoch 4, Step 140, Loss 0.0010
# (launch_and_fit pid=6127) Epoch 4, Valid Accuracy 92.86%
# (launch_and_fit pid=6127) [INFO] Patience 5 remaining
# (launch_and_fit pid=6127) Epoch 5, Step 0, Loss 0.0123
# (launch_and_fit pid=6127) Epoch 5, Step 10, Loss 0.0005
# (launch_and_fit pid=6127) Epoch 5, Step 20, Loss 0.0005
# (launch_and_fit pid=6127) Epoch 5, Step 30, Loss 0.0007
# (launch_and_fit pid=6127) Epoch 5, Step 40, Loss 0.5153
# (launch_and_fit pid=6127) Epoch 5, Step 50, Loss 0.0177
# (launch_and_fit pid=6127) Epoch 5, Step 60, Loss 0.0004
# (launch_and_fit pid=6127) Epoch 5, Step 70, Loss 0.0096
# (launch_and_fit pid=6127) Epoch 5, Step 80, Loss 0.0018
# (launch_and_fit pid=6127) Epoch 5, Step 90, Loss 0.0057
# (launch_and_fit pid=6127) Epoch 5, Step 100, Loss 0.0040
# (launch_and_fit pid=6127) Epoch 5, Step 110, Loss 0.0012
# (launch_and_fit pid=6127) Epoch 5, Step 120, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 5, Step 130, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 5, Step 140, Loss 0.0010
# (launch_and_fit pid=6127) Epoch 5, Valid Accuracy 93.65%
# (launch_and_fit pid=6127) [INFO] Patience 4 remaining
# (launch_and_fit pid=6127) Epoch 6, Step 0, Loss 0.0116
# (launch_and_fit pid=6127) Epoch 6, Step 10, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 6, Step 20, Loss 0.0025
# (launch_and_fit pid=6127) Epoch 6, Step 30, Loss 0.0212
# (launch_and_fit pid=6127) Epoch 6, Step 40, Loss 0.0071
# (launch_and_fit pid=6127) Epoch 6, Step 50, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 6, Step 60, Loss 0.0022
# (launch_and_fit pid=6127) Epoch 6, Step 70, Loss 0.0313
# (launch_and_fit pid=6127) Epoch 6, Step 80, Loss 0.0004
# (launch_and_fit pid=6127) Epoch 6, Step 90, Loss 0.0010
# (launch_and_fit pid=6127) Epoch 6, Step 100, Loss 0.0704
# (launch_and_fit pid=6127) Epoch 6, Step 110, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 6, Step 120, Loss 0.0013
# (launch_and_fit pid=6127) Epoch 6, Step 130, Loss 0.0106
# (launch_and_fit pid=6127) Epoch 6, Step 140, Loss 0.0052
# (launch_and_fit pid=6127) Epoch 6, Valid Accuracy 94.44%
# (launch_and_fit pid=6127) [INFO] Patience 3 remaining
# (launch_and_fit pid=6127) Epoch 7, Step 0, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 7, Step 10, Loss 0.0003
# (launch_and_fit pid=6127) Epoch 7, Step 20, Loss 0.0027
# (launch_and_fit pid=6127) Epoch 7, Step 30, Loss 0.0476
# (launch_and_fit pid=6127) Epoch 7, Step 40, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 7, Step 50, Loss 0.0194
# (launch_and_fit pid=6127) Epoch 7, Step 60, Loss 0.0003
# (launch_and_fit pid=6127) Epoch 7, Step 70, Loss 0.0002
# (launch_and_fit pid=6127) Epoch 7, Step 80, Loss 0.0009
# (launch_and_fit pid=6127) Epoch 7, Step 90, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 7, Step 100, Loss 0.0008
# (launch_and_fit pid=6127) Epoch 7, Step 110, Loss 0.0004
# (launch_and_fit pid=6127) Epoch 7, Step 120, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 7, Step 130, Loss 0.0212
# (launch_and_fit pid=6127) Epoch 7, Step 140, Loss 0.0154
# (launch_and_fit pid=6127) Epoch 7, Valid Accuracy 96.83%
# (launch_and_fit pid=6127) Epoch 8, Step 0, Loss 0.0022
# (launch_and_fit pid=6127) Epoch 8, Step 10, Loss 0.0003
# (launch_and_fit pid=6127) Epoch 8, Step 20, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 8, Step 30, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 8, Step 40, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 8, Step 50, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 8, Step 60, Loss 0.3781
# (launch_and_fit pid=6127) Epoch 8, Step 70, Loss 0.0064
# (launch_and_fit pid=6127) Epoch 8, Step 80, Loss 0.0060
# (launch_and_fit pid=6127) Epoch 8, Step 90, Loss 0.0363
# (launch_and_fit pid=6127) Epoch 8, Step 100, Loss 0.0017
# (launch_and_fit pid=6127) Epoch 8, Step 110, Loss 0.0355
# (launch_and_fit pid=6127) Epoch 8, Step 120, Loss 0.0064
# (launch_and_fit pid=6127) Epoch 8, Step 130, Loss 0.0242
# (launch_and_fit pid=6127) Epoch 8, Step 140, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 8, Valid Accuracy 93.65%
# (launch_and_fit pid=6127) [INFO] Patience 5 remaining
# (launch_and_fit pid=6127) Epoch 9, Step 0, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 9, Step 10, Loss 0.0200
# (launch_and_fit pid=6127) Epoch 9, Step 20, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 9, Step 30, Loss 0.0003
# (launch_and_fit pid=6127) Epoch 9, Step 40, Loss 0.0240
# (launch_and_fit pid=6127) Epoch 9, Step 50, Loss 0.0002
# (launch_and_fit pid=6127) Epoch 9, Step 60, Loss 0.0037
# (launch_and_fit pid=6127) Epoch 9, Step 70, Loss 0.0003
# (launch_and_fit pid=6127) Epoch 9, Step 80, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 9, Step 90, Loss 0.0016
# (launch_and_fit pid=6127) Epoch 9, Step 100, Loss 0.3883
# (launch_and_fit pid=6127) Epoch 9, Step 110, Loss 0.0004
# (launch_and_fit pid=6127) Epoch 9, Step 120, Loss 0.0031
# (launch_and_fit pid=6127) Epoch 9, Step 130, Loss 0.0273
# (launch_and_fit pid=6127) Epoch 9, Step 140, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 9, Valid Accuracy 91.27%
# (launch_and_fit pid=6127) [INFO] Patience 4 remaining
# (launch_and_fit pid=6127) Epoch 10, Step 0, Loss 0.0020
# (launch_and_fit pid=6127) Epoch 10, Step 10, Loss 0.7706
# (launch_and_fit pid=6127) Epoch 10, Step 20, Loss 0.0051
# (launch_and_fit pid=6127) Epoch 10, Step 30, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 10, Step 40, Loss 0.0032
# (launch_and_fit pid=6127) Epoch 10, Step 50, Loss 0.0002
# (launch_and_fit pid=6127) Epoch 10, Step 60, Loss 0.0040
# (launch_and_fit pid=6127) Epoch 10, Step 70, Loss 0.0029
# (launch_and_fit pid=6127) Epoch 10, Step 80, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 10, Step 90, Loss 0.0020
# (launch_and_fit pid=6127) Epoch 10, Step 100, Loss 0.0027
# (launch_and_fit pid=6127) Epoch 10, Step 110, Loss 0.0037
# (launch_and_fit pid=6127) Epoch 10, Step 120, Loss 0.0022
# (launch_and_fit pid=6127) Epoch 10, Step 130, Loss 0.0058
# (launch_and_fit pid=6127) Epoch 10, Step 140, Loss 0.0002
# (launch_and_fit pid=6127) Epoch 10, Valid Accuracy 95.24%
# (launch_and_fit pid=6127) Epoch 11, Step 0, Loss 0.0002
# (launch_and_fit pid=6127) Epoch 11, Step 10, Loss 0.0003
# (launch_and_fit pid=6127) Epoch 11, Step 20, Loss 0.0006
# (launch_and_fit pid=6127) Epoch 11, Step 30, Loss 0.0004
# (launch_and_fit pid=6127) Epoch 11, Step 40, Loss 0.0007
# (launch_and_fit pid=6127) Epoch 11, Step 50, Loss 0.0016
# (launch_and_fit pid=6127) Epoch 11, Step 60, Loss 0.0023
# (launch_and_fit pid=6127) Epoch 11, Step 70, Loss 0.1076
# (launch_and_fit pid=6127) Epoch 11, Step 80, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 11, Step 90, Loss 0.0002
# (launch_and_fit pid=6127) Epoch 11, Step 100, Loss 0.0038
# (launch_and_fit pid=6127) Epoch 11, Step 110, Loss 0.0004
# (launch_and_fit pid=6127) Epoch 11, Step 120, Loss 0.0011
# (launch_and_fit pid=6127) Epoch 11, Step 130, Loss 0.0003
# (launch_and_fit pid=6127) Epoch 11, Step 140, Loss 0.0409
# (launch_and_fit pid=6127) Epoch 11, Valid Accuracy 91.27%
# (launch_and_fit pid=6127) [INFO] Patience 5 remaining
# (launch_and_fit pid=6127) Epoch 12, Step 0, Loss 0.0119
# (launch_and_fit pid=6127) Epoch 12, Step 10, Loss 0.0002
# (launch_and_fit pid=6127) Epoch 12, Step 20, Loss 0.0046
# (launch_and_fit pid=6127) Epoch 12, Step 30, Loss 0.0030
# (launch_and_fit pid=6127) Epoch 12, Step 40, Loss 0.0012
# (launch_and_fit pid=6127) Epoch 12, Step 50, Loss 0.0054
# (launch_and_fit pid=6127) Epoch 12, Step 60, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 12, Step 70, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 12, Step 80, Loss 0.0023
# (launch_and_fit pid=6127) Epoch 12, Step 90, Loss 0.0002
# (launch_and_fit pid=6127) Epoch 12, Step 100, Loss 0.0007
# (launch_and_fit pid=6127) Epoch 12, Step 110, Loss 0.0072
# (launch_and_fit pid=6127) Epoch 12, Step 120, Loss 0.0006
# (launch_and_fit pid=6127) Epoch 12, Step 130, Loss 0.0012
# (launch_and_fit pid=6127) Epoch 12, Step 140, Loss 0.0010
# (launch_and_fit pid=6127) Epoch 12, Valid Accuracy 92.86%
# (launch_and_fit pid=6127) [INFO] Patience 4 remaining
# (launch_and_fit pid=6127) Epoch 13, Step 0, Loss 0.0052
# (launch_and_fit pid=6127) Epoch 13, Step 10, Loss 0.2984
# (launch_and_fit pid=6127) Epoch 13, Step 20, Loss 0.0104
# (launch_and_fit pid=6127) Epoch 13, Step 30, Loss 0.0003
# (launch_and_fit pid=6127) Epoch 13, Step 40, Loss 0.0058
# (launch_and_fit pid=6127) Epoch 13, Step 50, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 13, Step 60, Loss 0.0108
# (launch_and_fit pid=6127) Epoch 13, Step 70, Loss 0.0019
# (launch_and_fit pid=6127) Epoch 13, Step 80, Loss 0.0875
# (launch_and_fit pid=6127) Epoch 13, Step 90, Loss 0.0006
# (launch_and_fit pid=6127) Epoch 13, Step 100, Loss 0.1036
# (launch_and_fit pid=6127) Epoch 13, Step 110, Loss 0.0007
# (launch_and_fit pid=6127) Epoch 13, Step 120, Loss 0.0005
# (launch_and_fit pid=6127) Epoch 13, Step 130, Loss 0.0547
# (launch_and_fit pid=6127) Epoch 13, Step 140, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 13, Valid Accuracy 91.27%
# (launch_and_fit pid=6127) [INFO] Patience 3 remaining
# (launch_and_fit pid=6127) Epoch 14, Step 0, Loss 0.0148
# (launch_and_fit pid=6127) Epoch 14, Step 10, Loss 0.0100
# (launch_and_fit pid=6127) Epoch 14, Step 20, Loss 0.0041
# (launch_and_fit pid=6127) Epoch 14, Step 30, Loss 0.0002
# (launch_and_fit pid=6127) Epoch 14, Step 40, Loss 0.0009
# (launch_and_fit pid=6127) Epoch 14, Step 50, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 14, Step 60, Loss 0.0397
# (launch_and_fit pid=6127) Epoch 14, Step 70, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 14, Step 80, Loss 0.0003
# (launch_and_fit pid=6127) Epoch 14, Step 90, Loss 0.4222
# (launch_and_fit pid=6127) Epoch 14, Step 100, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 14, Step 110, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 14, Step 120, Loss 1.2512
# (launch_and_fit pid=6127) Epoch 14, Step 130, Loss 0.0008
# (launch_and_fit pid=6127) Epoch 14, Step 140, Loss 0.0058
# (launch_and_fit pid=6127) Epoch 00015: reducing learning rate of group 0 to 1.0000e-04.
# (launch_and_fit pid=6127) Epoch 14, Valid Accuracy 92.06%
# (launch_and_fit pid=6127) [INFO] Patience 2 remaining
# (launch_and_fit pid=6127) Epoch 15, Step 0, Loss 0.0252
# (launch_and_fit pid=6127) Epoch 15, Step 10, Loss 0.0070
# (launch_and_fit pid=6127) Epoch 15, Step 20, Loss 0.0008
# (launch_and_fit pid=6127) Epoch 15, Step 30, Loss 0.2391
# (launch_and_fit pid=6127) Epoch 15, Step 40, Loss 0.0183
# (launch_and_fit pid=6127) Epoch 15, Step 50, Loss 0.3361
# (launch_and_fit pid=6127) Epoch 15, Step 60, Loss 0.0025
# (launch_and_fit pid=6127) Epoch 15, Step 70, Loss 0.3911
# (launch_and_fit pid=6127) Epoch 15, Step 80, Loss 0.0022
# (launch_and_fit pid=6127) Epoch 15, Step 90, Loss 0.0000
# (launch_and_fit pid=6127) Epoch 15, Step 100, Loss 0.0003
# (launch_and_fit pid=6127) Epoch 15, Step 110, Loss 0.0031
# (launch_and_fit pid=6127) Epoch 15, Step 120, Loss 0.0005
# (launch_and_fit pid=6127) Epoch 15, Step 130, Loss 0.0100
# (launch_and_fit pid=6127) Epoch 15, Step 140, Loss 0.0121
# (launch_and_fit pid=6127) Epoch 15, Valid Accuracy 92.86%
# (launch_and_fit pid=6127) [INFO] Patience 1 remaining
# (launch_and_fit pid=6127) Epoch 16, Step 0, Loss 0.0014
# (launch_and_fit pid=6127) Epoch 16, Step 10, Loss 0.0004
# (launch_and_fit pid=6127) Epoch 16, Step 20, Loss 0.0257
# (launch_and_fit pid=6127) Epoch 16, Step 30, Loss 0.0003
# (launch_and_fit pid=6127) Epoch 16, Step 40, Loss 0.0009
# (launch_and_fit pid=6127) Epoch 16, Step 50, Loss 0.0087
# (launch_and_fit pid=6127) Epoch 16, Step 60, Loss 0.0001
# (launch_and_fit pid=6127) Epoch 16, Step 70, Loss 0.0097
# (launch_and_fit pid=6127) Epoch 16, Step 80, Loss 0.0091
# (launch_and_fit pid=6127) Epoch 16, Step 90, Loss 0.0021
# (launch_and_fit pid=6127) Epoch 16, Step 100, Loss 0.0021
# (launch_and_fit pid=6127) Epoch 16, Step 110, Loss 0.3160
# (launch_and_fit pid=6127) Epoch 16, Step 120, Loss 0.0095
# (launch_and_fit pid=6127) Epoch 16, Step 130, Loss 0.3048
# (launch_and_fit pid=6127) Epoch 16, Step 140, Loss 0.0056
# (launch_and_fit pid=6127) Epoch 16, Valid Accuracy 92.06%
# (launch_and_fit pid=6127) [Early Stopping] Epoch 16, Valid Accuracy 92.06%, Valid Loss 0.2705
# (launch_and_fit pid=6127) [Client 2] get_parameters
# DEBUG flower 2023-12-12 02:31:59,652 | server.py:277 | fit_round received 2 results and 0 failures
# INFO flower 2023-12-12 02:32:14,148 | server.py:158 | fit progress: (10, nan, {'val_accuracy': 0.25396825396825395, 'test_accuracy': 0.27014218009478674}, 7297.797859589)
# INFO flower 2023-12-12 02:32:14,149 | server.py:209 | evaluate_round: no clients selected, cancel
# INFO flower 2023-12-12 02:32:14,150 | server.py:182 | FL finished in 7297.799520656
# INFO flower 2023-12-12 02:32:14,157 | app.py:149 | app_fit: losses_distributed []
# INFO flower 2023-12-12 02:32:14,158 | app.py:150 | app_fit: metrics_distributed {}
# INFO flower 2023-12-12 02:32:14,159 | app.py:151 | app_fit: losses_centralized [(0, 0.17667243310383388), (1, nan), (2, nan), (3, nan), (4, nan), (5, nan), (6, nan), (7, nan), (8, nan), (9, nan), (10, nan)]
# INFO flower 2023-12-12 02:32:14,159 | app.py:152 | app_fit: metrics_centralized {'val_accuracy': [(0, 0.36507936507936506), (1, 0.25396825396825395), (2, 0.25396825396825395), (3, 0.25396825396825395), (4, 0.25396825396825395), (5, 0.25396825396825395), (6, 0.25396825396825395), (7, 0.25396825396825395), (8, 0.25396825396825395), (9, 0.25396825396825395), (10, 0.25396825396825395)], 'test_accuracy': [(0, 0.36729857819905215), (1, 0.27014218009478674), (2, 0.27014218009478674), (3, 0.27014218009478674), (4, 0.27014218009478674), (5, 0.27014218009478674), (6, 0.27014218009478674), (7, 0.27014218009478674), (8, 0.27014218009478674), (9, 0.27014218009478674), (10, 0.27014218009478674)]}

# %% [markdown]
# ## Plotting Grpahs

# %%
import matplotlib.pyplot as plt

rounds = [x for x in range(len(res.metrics_centralized['val_accuracy']))]
val_accuracies = [x[1] for x in res.metrics_centralized['val_accuracy']]
test_accuracies = [x[1] for x in res.metrics_centralized['test_accuracy']]

# Plotting
plt.figure(figsize=(8, 6))
# plt.ylim([-1,2])
plt.plot(rounds, val_accuracies, 'b',marker="o", label='Validation Accuracy')
plt.plot(rounds, test_accuracies, 'r',marker="o", label='Test Accuracy')
# plt.plot(epochs, val_losses, 'r', label='Validation Loss')
plt.title('Validation and Test Accuracy')
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

rounds = range(0, len(res.losses_centralized))
val_losses = [x[1] for x in res.losses_centralized]

# Plotting
plt.figure(figsize=(8, 6))
# plt.ylim([-1,2])
plt.plot(rounds, val_losses, 'b', marker="o", label='Validation Loss')
# plt.plot(epochs, val_losses, 'r', label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Rounds')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
res
# Out:
# History (loss, centralized):
# 	round 0: 0.17667243310383388
# 	round 1: nan
# 	round 2: nan
# 	round 3: nan
# 	round 4: nan
# 	round 5: nan
# 	round 6: nan
# 	round 7: nan
# 	round 8: nan
# 	round 9: nan
# 	round 10: nan
# History (metrics, centralized):
# {'val_accuracy': [(0, 0.36507936507936506), (1, 0.25396825396825395), (2, 0.25396825396825395), (3, 0.25396825396825395), (4, 0.25396825396825395), (5, 0.25396825396825395), (6, 0.25396825396825395), (7, 0.25396825396825395), (8, 0.25396825396825395), (9, 0.25396825396825395), (10, 0.25396825396825395)], 'test_accuracy': [(0, 0.36729857819905215), (1, 0.27014218009478674), (2, 0.27014218009478674), (3, 0.27014218009478674), (4, 0.27014218009478674), (5, 0.27014218009478674), (6, 0.27014218009478674), (7, 0.27014218009478674), (8, 0.27014218009478674), (9, 0.27014218009478674), (10, 0.27014218009478674)]}
