# %% [markdown]
# # Federated Learning In ResNet - Eye Disease Classifications

# %% [markdown]
# ### Installing dependencies

# %%
# !pip install flwr["simulation"]==0.18.0 torch torchvision
# Out:
# Collecting flwr[simulation]==0.18.0
#   Downloading flwr-0.18.0-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.2/106.2 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.0.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.15.1)
# Collecting google<3.0.0,>=2.0.3 (from flwr[simulation]==0.18.0)
#   Downloading google-2.0.3-py2.py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 1.9 MB/s eta 0:00:00
# Collecting grpcio<=1.43.0,>=1.27.2 (from flwr[simulation]==0.18.0)
#   Downloading grpcio-1.43.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>=1.19.0 in /opt/conda/lib/python3.10/site-packages (from flwr[simulation]==0.18.0) (1.24.3)
# Requirement already satisfied: protobuf<4.0.0,>=3.12.1 in /opt/conda/lib/python3.10/site-packages (from flwr[simulation]==0.18.0) (3.20.3)
# Collecting ray[default]<2.0.0,>=1.9.2 (from flwr[simulation]==0.18.0)
#   Downloading ray-1.13.0-cp310-cp310-manylinux2014_x86_64.whl (54.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 MB 937.9 kB/s eta 0:00:00
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (10.1.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from google<3.0.0,>=2.0.3->flwr[simulation]==0.18.0) (4.12.2)
# Requirement already satisfied: six>=1.5.2 in /opt/conda/lib/python3.10/site-packages (from grpcio<=1.43.0,>=1.27.2->flwr[simulation]==0.18.0) (1.16.0)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (23.1.0)
# Collecting click<=8.0.4,>=7.0 (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0)
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 643.5 kB/s eta 0:00:00
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (4.19.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (1.0.5)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (6.0.1)
# Requirement already satisfied: aiosignal in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (1.3.1)
# Requirement already satisfied: frozenlist in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (1.4.0)
# Requirement already satisfied: virtualenv in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (20.21.0)
# Requirement already satisfied: aiohttp>=3.7 in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (3.8.5)
# Requirement already satisfied: aiohttp-cors in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.7.0)
# Requirement already satisfied: colorful in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.5.5)
# Requirement already satisfied: py-spy>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.3.14)
# Requirement already satisfied: gpustat>=1.0.0b1 in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (1.0.0)
# Requirement already satisfied: opencensus in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.11.2)
# Collecting prometheus-client<0.14.0,>=0.7.1 (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0)
#   Downloading prometheus_client-0.13.1-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 708.6 kB/s eta 0:00:00
# Requirement already satisfied: smart-open in /opt/conda/lib/python3.10/site-packages (from ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (6.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (1.9.2)
# Requirement already satisfied: nvidia-ml-py<=11.495.46,>=11.450.129 in /opt/conda/lib/python3.10/site-packages (from gpustat>=1.0.0b1->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (11.495.46)
# Requirement already satisfied: psutil>=5.6.0 in /opt/conda/lib/python3.10/site-packages (from gpustat>=1.0.0b1->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (5.9.3)
# Requirement already satisfied: blessed>=1.17.1 in /opt/conda/lib/python3.10/site-packages (from gpustat>=1.0.0b1->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (1.20.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->google<3.0.0,>=2.0.3->flwr[simulation]==0.18.0) (2.3.2.post1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.9.2)
# Requirement already satisfied: opencensus-context>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from opencensus->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from opencensus->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (2.11.1)
# Requirement already satisfied: distlib<1,>=0.3.6 in /opt/conda/lib/python3.10/site-packages (from virtualenv->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.3.7)
# Collecting platformdirs<4,>=2.4 (from virtualenv->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0)
#   Obtaining dependency information for platformdirs<4,>=2.4 from https://files.pythonhosted.org/packages/56/29/3ec311dc18804409ecf0d2b09caa976f3ae6215559306b5b530004e11156/platformdirs-3.11.0-py3-none-any.whl.metadata
#   Downloading platformdirs-3.11.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: wcwidth>=0.1.4 in /opt/conda/lib/python3.10/site-packages (from blessed>=1.17.1->gpustat>=1.0.0b1->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.2.6)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (1.60.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (2.22.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (4.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<2.0.0,>=1.9.2->flwr[simulation]==0.18.0) (0.4.8)
# Downloading platformdirs-3.11.0-py3-none-any.whl (17 kB)
# Installing collected packages: prometheus-client, platformdirs, grpcio, click, google, flwr, ray
#   Attempting uninstall: prometheus-client
#     Found existing installation: prometheus-client 0.17.1
#     Uninstalling prometheus-client-0.17.1:
#       Successfully uninstalled prometheus-client-0.17.1
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 4.1.0
#     Uninstalling platformdirs-4.1.0:
#       Successfully uninstalled platformdirs-4.1.0
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.51.1
#     Uninstalling grpcio-1.51.1:
#       Successfully uninstalled grpcio-1.51.1
#   Attempting uninstall: click
#     Found existing installation: click 8.1.7
#     Uninstalling click-8.1.7:
#       Successfully uninstalled click-8.1.7
#   Attempting uninstall: ray
#     Found existing installation: ray 2.6.3
#     Uninstalling ray-2.6.3:
#       Successfully uninstalled ray-2.6.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.7 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# dask 2023.12.0 requires click>=8.1, but you have click 8.0.4 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2023.12.0 which is incompatible.
# dask-cuda 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.12.0 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.3 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2023.12.0 which is incompatible.
# dask-cudf 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.12.0 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.3 which is incompatible.
# fitter 1.6.0 requires click<9.0.0,>=8.1.6, but you have click 8.0.4 which is incompatible.
# flask 3.0.0 requires click>=8.1.3, but you have click 8.0.4 which is incompatible.
# google-cloud-pubsub 2.18.3 requires grpcio<2.0dev,>=1.51.3, but you have grpcio 1.43.0 which is incompatible.
# grpc-google-iam-v1 0.12.6 requires grpcio<2.0.0dev,>=1.44.0, but you have grpcio 1.43.0 which is incompatible.
# grpcio-status 1.48.1 requires grpcio>=1.48.1, but you have grpcio 1.43.0 which is incompatible.
# jupyterlab 4.0.5 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.0.1 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.0.1 requires jupyterlab<5.0.0a0,>=4.0.6, but you have jupyterlab 4.0.5 which is incompatible.
# kfp 2.0.1 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2023.12.0 which is incompatible.
# raft-dask 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.12.0 which is incompatible.
# tensorboard 2.13.0 requires grpcio>=1.48.2, but you have grpcio 1.43.0 which is incompatible.
# tensorflowjs 4.14.0 requires packaging~=23.1, but you have packaging 21.3 which is incompatible.
# Successfully installed click-8.0.4 flwr-0.18.0 google-2.0.3 grpcio-1.43.0 platformdirs-3.11.0 prometheus-client-0.13.1 ray-1.13.0

# %%
from collections import OrderedDict
from typing import Dict, List, Optional, Tuple

import flwr as fl
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, utils
torch.manual_seed(42)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Training on {DEVICE}")
# Out:
# Training on cuda

# %% [markdown]
# ### Data loading

# %%
class EyeImageDataset(torch.utils.data.Dataset):
    def __init__(self, root_dir, transform=None):
        self.dataset = datasets.ImageFolder(root=root_dir, transform=transform)
        self.classes = self.dataset.classes

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        return self.dataset[idx]

# %%
root_directory = '/kaggle/input/dataset/'

data_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize(size = (224, 224)),
    transforms.RandomRotation(degrees=5),
    transforms.RandomHorizontalFlip(p=0.5),
])

dataset = EyeImageDataset(root_dir=root_directory, transform=data_transform)

# %%
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [int(len(dataset)*0.9), len(dataset)-int(len(dataset)*0.9)])

# %% [markdown]
# ## Setting number of clients to simulate Federated Learning

# %%
NUM_CLIENTS = 3

# %%
num_clients = NUM_CLIENTS

# Split training set into `num_clients` partitions to simulate different local datasets
partition_size = len(train_dataset) // num_clients
lengths = [partition_size] * num_clients
datasets = random_split(train_dataset, lengths, torch.Generator().manual_seed(42))

# Split each partition into train/val and create DataLoader
train_loaders = []
val_loaders = []
for ds in datasets:
    len_val = len(ds) // 10  # 10 % validation set
    len_train = len(ds) - len_val
    lengths = [len_train, len_val]
    ds_train, ds_val = random_split(ds, lengths, torch.Generator().manual_seed(42))
    train_loaders.append(DataLoader(ds_train, batch_size=8, shuffle=True))
    val_loaders.append(DataLoader(ds_val, batch_size=8,shuffle=True))
test_loader = DataLoader(test_dataset, batch_size=8)

# %% [markdown]
# ### Model training/evaluation

# %%
import torch
import torchvision.models as models
from torchvision.models import resnet50, ResNet50_Weights, resnet18, ResNet18_Weights
import torch.nn as nn
import tqdm

# %%
model = models.resnet50(weights = ResNet50_Weights.IMAGENET1K_V1)

ct=0
for child in model.children():
    ct += 1
    if ct < 7:
        for param in child.parameters():
            param.requires_grad = False
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 220MB/s]

# %%
# modify the classifier layer
model.fc = nn.Sequential(nn.Linear(2048, 1024), nn.ReLU(), nn.Linear(1024, 1024), nn.ReLU(), nn.Linear(1024,4))

# %%
model = model.to(DEVICE)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=1024, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=1024, out_features=4, bias=True)
#   )
# )

# %%
def evaluate(model, data_loader, criterion):
    """Evaluate the model on the given dataset."""
    # Set the model to evaluation mode.
    model.eval()
    correct = 0
    val_loss = 0
    count = 0
    # The `torch.no_grad()` context will turn off gradients for efficiency.
    with torch.no_grad():
        for images, labels in (data_loader):
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            output = model(images)
            pred = output.argmax(dim=1)
            loss = criterion(output, labels)
            correct += (pred == labels).sum().item()
            val_loss += loss.item() 
            count += 1
    return correct / len(data_loader.dataset), val_loss/count


def train(model, n_epoch, optimizer, scheduler, criterion, train_loader, valid_loader):
    """Train the model on the given dataset."""
    loss_ref = float('inf')
    for epoch in range(n_epoch):
        # Set the model to training mode.
        model.train()
        for step, (images, labels) in enumerate(train_loader):
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            # 1. Clear previous gradients.
            optimizer.zero_grad()
            # 2. Forward pass. Calculate the output of the model.
            output = model(images)
            # 3. Calculate the loss.
            loss = criterion(output, labels)
            # 4. Calculate the gradients. PyTorch does this for us!
            loss.backward()
            # 5. Update the model parameters.
            optimizer.step()
            if step % 10 == 0:
                print(f"Epoch {epoch}, Step {step}, Loss {loss.item():.4f}")
        
        acc, val_loss = evaluate(model, valid_loader, criterion)
        scheduler.step(val_loss)
        print(f"Epoch {epoch}, Valid Accuracy {acc * 100:.2f}%") 
        
        if val_loss < loss_ref:
            patience = 5
            loss_ref = val_loss
        else:
            if patience == 0:
                print(f"[Early Stopping] Epoch {epoch}, Valid Accuracy {acc * 100:.2f}%, Valid Loss {val_loss:.4f}")
                return
            print(f"[INFO] Patience {patience} remaining")
            patience-=1

# %%
def get_parameters(net) -> List[np.ndarray]:
    return [val.cpu().numpy() for _, val in net.state_dict().items()]


def set_parameters(net, parameters: List[np.ndarray]):
    params_dict = zip(net.state_dict().keys(), parameters)
    state_dict = OrderedDict(
            {
                k: torch.Tensor(v) if v.shape != torch.Size([]) else torch.Tensor([0])
                for k, v in params_dict
            }
        )
    net.load_state_dict(state_dict, strict=True)

def test(net, testloader):
    """Evaluate the network on the entire test set."""
    criterion = torch.nn.CrossEntropyLoss()
    correct, total, loss = 0, 0, 0.0
    net.eval()
    with torch.no_grad():
        for images, labels in testloader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = net(images)
            loss += criterion(outputs, labels).item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    loss /= len(testloader.dataset)
    accuracy = correct / total
    return loss, accuracy

# %% [markdown]
# ### Flower client
#
# Setting flower client. These flower clients represent a client on the federated learning model.

# %%
from logging import INFO, DEBUG
from flwr.common.logger import log

class FlowerClient(fl.client.NumPyClient):
    def __init__(self, cid, net, trainloader, valloader):
        self.cid = cid
        self.model = model.to(DEVICE)
        self.trainloader = trainloader
        self.valloader = valloader

    def get_parameters(self):
        print(f"[Client {self.cid}] get_parameters")
        return [val.cpu().numpy() for _, val in self.model.state_dict().items()]
    
    def set_parameters(self, parameters: List[np.ndarray]) -> None:
        # Set model parameters from a list of NumPy ndarrays
        params_dict = zip(self.model.state_dict().keys(), parameters)
        state_dict = OrderedDict(
                    {
                        k: torch.Tensor(v) if v.shape != torch.Size([]) else torch.Tensor([0])
                        for k, v in params_dict
                    }
                )
        self.model.load_state_dict(state_dict, strict=True)

    def fit(self, parameters, config):
        print(f"[Client {self.cid}] fit, config: {config}")
        self.set_parameters(parameters)
        lr = 1e-3
        gamma = 0.9
        criterion = nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=lr)
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, verbose=True)

        n_epoch = 20
        train(self.model, n_epoch, optimizer, scheduler,criterion,self.trainloader, self.valloader)
        return self.get_parameters(), len(self.trainloader), {}

    def evaluate(self, parameters, config):
        print(f"[Client {self.cid}] evaluate, config: {config}")
        self.set_parameters(parameters)
        criterion = nn.CrossEntropyLoss()
        accuracy, loss = evaluate(self.model, self.valloader, criterion)
        return float(loss), len(self.valloader), {"accuracy": float(accuracy)}


def client_fn(cid) -> FlowerClient:
    train_loader = train_loaders[int(cid)]
    val_loader = val_loaders[int(cid)]
    return FlowerClient(cid, model, train_loader, val_loader)

# %% [markdown]
# ## Server Side Evaluation
# We evalaute the accumulated model on the server after every federated round against the validation and test set

# %%
def get_evaluate_fn():

    def evaluate(
        parameters:  List[np.ndarray],
    ) -> Optional[Tuple[float, Dict[str, fl.common.Scalar]]]:
        params_dict = zip(model.state_dict().keys(), parameters)
        state_dict = OrderedDict({k: torch.tensor(v) for k, v in params_dict})
        model.load_state_dict(state_dict, strict=True)
        val_loss, val_accuracy = test(model, val_loaders[0])
        test_loss, test_accuracy = test(model, test_loader)
        return val_loss, {"val_accuracy": val_accuracy, "test_accuracy": test_accuracy}

    return evaluate
# The `evaluate` function will be by Flower called after every round
def evaluate_server(
    parameters: List[np.ndarray],
) -> Optional[Tuple[float, Dict[str, fl.common.Scalar]]]:
    net = model.to(DEVICE)
    valloader = val_loaders[0]
    set_parameters(net, parameters)  # Update model with the latest parameters
    loss, accuracy = test(net, valloader)
    print(f"Server-side evaluation loss {loss} / accuracy {accuracy}")
    return loss, {"accuracy": accuracy}

# %% [markdown]
# ## Server Side Initialization and Simulation
# We make use of FedAvg to accumulate the paramters from all the clients on the server.

# %%
model_params = get_parameters(model.to(DEVICE))
strategy = fl.server.strategy.FedAvg(
    fraction_fit=0.3,
    fraction_eval=0.3,
    min_fit_clients=2,
    min_eval_clients=2,
    min_available_clients=NUM_CLIENTS,
    initial_parameters=fl.common.weights_to_parameters(get_parameters(model.to(DEVICE))),
    eval_fn=get_evaluate_fn(),  # Pass the evaluation function
    
)

#Start Simulation
res = fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=NUM_CLIENTS,
    num_rounds=10,
    strategy=strategy,
    client_resources = {'num_cpus': 4, 'num_gpus': 2}
)
# Out:
# INFO flower 2023-12-12 00:08:05,205 | app.py:144 | Ray initialized with resources: {'node:172.19.2.2': 1.0, 'GPU': 2.0, 'CPU': 4.0, 'accelerator_type:T4': 1.0, 'memory': 18803311412.0, 'object_store_memory': 9401655705.0}
# INFO flower 2023-12-12 00:08:05,208 | app.py:153 | Starting Flower simulation running: {'num_rounds': 10}
# INFO flower 2023-12-12 00:08:05,209 | server.py:128 | Initializing global parameters
# INFO flower 2023-12-12 00:08:05,212 | server.py:323 | Using initial parameters provided by strategy
# INFO flower 2023-12-12 00:08:05,213 | server.py:130 | Evaluating initial parameters
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# INFO flower 2023-12-12 00:08:28,967 | server.py:133 | initial parameters (loss, other metrics): 0.17667243310383388, {'val_accuracy': 0.36507936507936506, 'test_accuracy': 0.36729857819905215}
# INFO flower 2023-12-12 00:08:28,968 | server.py:143 | FL starting
# DEBUG flower 2023-12-12 00:08:28,969 | server.py:265 | fit_round: strategy sampled 2 clients (out of 3)
# (launch_and_fit pid=301) [Client 1] fit, config: {}
# (launch_and_fit pid=301) /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# (launch_and_fit pid=301)   warnings.warn(
# (launch_and_fit pid=301) Epoch 0, Step 0, Loss 1.3850
# (launch_and_fit pid=301) Epoch 0, Step 10, Loss 1.8702
# (launch_and_fit pid=301) Epoch 0, Step 20, Loss 1.2586
# (launch_and_fit pid=301) Epoch 0, Step 30, Loss 1.1693
# (launch_and_fit pid=301) Epoch 0, Step 40, Loss 1.2889
# (launch_and_fit pid=301) Epoch 0, Step 50, Loss 0.9957
# (launch_and_fit pid=301) Epoch 0, Step 60, Loss 1.3310
# (launch_and_fit pid=301) Epoch 0, Step 70, Loss 0.7074
# (launch_and_fit pid=301) Epoch 0, Step 80, Loss 1.1537
# (launch_and_fit pid=301) Epoch 0, Step 90, Loss 0.5937
# (launch_and_fit pid=301) Epoch 0, Step 100, Loss 1.3508
# (launch_and_fit pid=301) Epoch 0, Step 110, Loss 0.7197
# (launch_and_fit pid=301) Epoch 0, Step 120, Loss 0.7786
# (launch_and_fit pid=301) Epoch 0, Step 130, Loss 1.4019
# (launch_and_fit pid=301) Epoch 0, Step 140, Loss 0.5240
# (launch_and_fit pid=301) Epoch 0, Valid Accuracy 63.49%
# (launch_and_fit pid=301) Epoch 1, Step 0, Loss 1.0348
# (launch_and_fit pid=301) Epoch 1, Step 10, Loss 0.7234
# (launch_and_fit pid=301) Epoch 1, Step 20, Loss 0.5750
# (launch_and_fit pid=301) Epoch 1, Step 30, Loss 0.5861
# (launch_and_fit pid=301) Epoch 1, Step 40, Loss 0.9197
# (launch_and_fit pid=301) Epoch 1, Step 50, Loss 0.9423
# (launch_and_fit pid=301) Epoch 1, Step 60, Loss 0.6965
# (launch_and_fit pid=301) Epoch 1, Step 70, Loss 1.2294
# (launch_and_fit pid=301) Epoch 1, Step 80, Loss 0.5258
# (launch_and_fit pid=301) Epoch 1, Step 90, Loss 0.2335
# (launch_and_fit pid=301) Epoch 1, Step 100, Loss 0.4581
# (launch_and_fit pid=301) Epoch 1, Step 110, Loss 0.6923
# (launch_and_fit pid=301) Epoch 1, Step 120, Loss 0.2786
# (launch_and_fit pid=301) Epoch 1, Step 130, Loss 0.9550
# (launch_and_fit pid=301) Epoch 1, Step 140, Loss 0.6793
# (launch_and_fit pid=301) Epoch 1, Valid Accuracy 76.19%
# (launch_and_fit pid=301) Epoch 2, Step 0, Loss 0.9425
# (launch_and_fit pid=301) Epoch 2, Step 10, Loss 0.5571
# (launch_and_fit pid=301) Epoch 2, Step 20, Loss 0.1412
# (launch_and_fit pid=775) Epoch 5, Step 130, Loss 0.0634
# (launch_and_fit pid=775) Epoch 5, Step 140, Loss 0.3458
# (launch_and_fit pid=775) Epoch 00006: reducing learning rate of group 0 to 1.0000e-04.
# (launch_and_fit pid=775) Epoch 5, Valid Accuracy 76.98%
# (launch_and_fit pid=775) [INFO] Patience 2 remaining
# (launch_and_fit pid=775) Epoch 6, Step 0, Loss 0.7828
# (launch_and_fit pid=775) Epoch 6, Step 10, Loss 0.1115
# (launch_and_fit pid=775) Epoch 6, Step 20, Loss 0.5202
# (launch_and_fit pid=775) Epoch 6, Step 30, Loss 0.1941
# (launch_and_fit pid=775) Epoch 6, Step 40, Loss 0.5416
# (launch_and_fit pid=775) Epoch 6, Step 50, Loss 0.1757
# (launch_and_fit pid=775) Epoch 6, Step 60, Loss 0.2183
# (launch_and_fit pid=775) Epoch 6, Step 70, Loss 1.1067
# (launch_and_fit pid=775) Epoch 6, Step 80, Loss 1.0503
# (launch_and_fit pid=775) Epoch 6, Step 90, Loss 0.2304
# (launch_and_fit pid=775) Epoch 6, Step 100, Loss 0.1312
# (launch_and_fit pid=775) Epoch 6, Step 110, Loss 0.3655
# (launch_and_fit pid=775) Epoch 6, Step 120, Loss 0.1574
# (launch_and_fit pid=775) Epoch 6, Step 130, Loss 0.1055
# (launch_and_fit pid=775) Epoch 6, Step 140, Loss 0.5202
# (launch_and_fit pid=775) Epoch 6, Valid Accuracy 82.54%
# (launch_and_fit pid=775) Epoch 7, Step 0, Loss 0.1573
# (launch_and_fit pid=775) Epoch 7, Step 10, Loss 0.1176
# (launch_and_fit pid=775) Epoch 7, Step 20, Loss 0.2678
# (launch_and_fit pid=775) Epoch 7, Step 30, Loss 0.6395
# (launch_and_fit pid=775) Epoch 7, Step 40, Loss 0.5537
# (launch_and_fit pid=775) Epoch 7, Step 50, Loss 0.0697
# (launch_and_fit pid=775) Epoch 7, Step 60, Loss 0.3712
# (launch_and_fit pid=775) Epoch 7, Step 70, Loss 0.1438
# (launch_and_fit pid=775) Epoch 7, Step 80, Loss 0.6245
# (launch_and_fit pid=775) Epoch 7, Step 90, Loss 0.4835
# (launch_and_fit pid=775) Epoch 7, Step 100, Loss 0.1979
# (launch_and_fit pid=775) Epoch 7, Step 110, Loss 0.3395
# (launch_and_fit pid=775) Epoch 7, Step 120, Loss 0.5546
# (launch_and_fit pid=775) Epoch 7, Step 130, Loss 0.0289
# (launch_and_fit pid=775) Epoch 7, Step 140, Loss 0.3221
# (launch_and_fit pid=775) Epoch 7, Valid Accuracy 83.33%
# (launch_and_fit pid=775) [INFO] Patience 5 remaining
# (launch_and_fit pid=775) Epoch 8, Step 0, Loss 0.0476
# (launch_and_fit pid=775) Epoch 8, Step 10, Loss 0.0818
# (launch_and_fit pid=775) Epoch 8, Step 20, Loss 0.1452
# (launch_and_fit pid=775) Epoch 8, Step 30, Loss 0.2577
# (launch_and_fit pid=775) Epoch 8, Step 40, Loss 0.0472
# (launch_and_fit pid=775) Epoch 8, Step 50, Loss 0.2573
# (launch_and_fit pid=775) Epoch 18, Step 140, Loss 0.1542
# (launch_and_fit pid=775) Epoch 18, Valid Accuracy 84.92%
# (launch_and_fit pid=775) [INFO] Patience 4 remaining
# (launch_and_fit pid=775) Epoch 19, Step 0, Loss 0.0636
# (launch_and_fit pid=775) Epoch 19, Step 10, Loss 0.0788
# (launch_and_fit pid=775) Epoch 19, Step 20, Loss 0.0676
# (launch_and_fit pid=775) Epoch 19, Step 30, Loss 0.4744
# (launch_and_fit pid=775) Epoch 19, Step 40, Loss 0.0510
# (launch_and_fit pid=775) Epoch 19, Step 50, Loss 0.1978
# (launch_and_fit pid=775) Epoch 19, Step 60, Loss 0.0555
# (launch_and_fit pid=775) Epoch 19, Step 70, Loss 0.2699
# (launch_and_fit pid=775) Epoch 19, Step 80, Loss 0.3325
# (launch_and_fit pid=775) Epoch 19, Step 90, Loss 0.0732
# (launch_and_fit pid=775) Epoch 19, Step 100, Loss 0.3651
# (launch_and_fit pid=775) Epoch 19, Step 110, Loss 0.2957
# (launch_and_fit pid=775) Epoch 19, Step 120, Loss 0.4993
# (launch_and_fit pid=775) Epoch 19, Step 130, Loss 0.1449
# (launch_and_fit pid=775) Epoch 19, Step 140, Loss 0.1855
# (launch_and_fit pid=775) Epoch 19, Valid Accuracy 84.13%
# (launch_and_fit pid=775) [INFO] Patience 3 remaining
# (launch_and_fit pid=775) [Client 2] get_parameters
# DEBUG flower 2023-12-12 00:27:22,879 | server.py:277 | fit_round received 2 results and 0 failures
# INFO flower 2023-12-12 00:27:34,683 | server.py:158 | fit progress: (1, 0.1584599633065481, {'val_accuracy': 0.5317460317460317, 'test_accuracy': 0.566350710900474}, 1145.7139144979997)
# INFO flower 2023-12-12 00:27:34,684 | server.py:209 | evaluate_round: no clients selected, cancel
# DEBUG flower 2023-12-12 00:27:34,685 | server.py:265 | fit_round: strategy sampled 2 clients (out of 3)
# (launch_and_fit pid=1243) [Client 0] fit, config: {}
# (launch_and_fit pid=1243) /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# (launch_and_fit pid=1243)   warnings.warn(
# (launch_and_fit pid=1243) Epoch 0, Step 0, Loss 1.0970
# (launch_and_fit pid=1243) Epoch 0, Step 10, Loss 0.5647
# (launch_and_fit pid=1243) Epoch 0, Step 20, Loss 0.4778
# (launch_and_fit pid=1243) Epoch 0, Step 30, Loss 0.6071
# (launch_and_fit pid=1243) Epoch 0, Step 40, Loss 0.5969
# (launch_and_fit pid=1243) Epoch 0, Step 50, Loss 0.1841
# (launch_and_fit pid=1243) Epoch 0, Step 60, Loss 0.2054
# (launch_and_fit pid=1243) Epoch 0, Step 70, Loss 0.2680
# (launch_and_fit pid=1243) Epoch 0, Step 80, Loss 0.2175
# (launch_and_fit pid=1243) Epoch 0, Step 90, Loss 0.3299
# (launch_and_fit pid=1243) Epoch 0, Step 100, Loss 0.1264
# (launch_and_fit pid=1243) Epoch 0, Step 110, Loss 0.3013
# (launch_and_fit pid=1243) Epoch 0, Step 120, Loss 0.3568
# (launch_and_fit pid=1243) Epoch 0, Step 130, Loss 0.2366
# (launch_and_fit pid=1243) Epoch 6, Step 10, Loss 0.0240
# (launch_and_fit pid=1243) Epoch 6, Step 20, Loss 0.0157
# (launch_and_fit pid=1243) Epoch 6, Step 30, Loss 0.0162
# (launch_and_fit pid=1243) Epoch 6, Step 40, Loss 0.0278
# (launch_and_fit pid=1243) Epoch 6, Step 50, Loss 0.8849
# (launch_and_fit pid=1243) Epoch 6, Step 60, Loss 0.0574
# (launch_and_fit pid=1243) Epoch 6, Step 70, Loss 0.2136
# ...
# (launch_and_fit pid=6191) Epoch 6, Step 20, Loss 0.0176
# (launch_and_fit pid=6191) Epoch 6, Step 30, Loss 0.0296
# (launch_and_fit pid=6191) Epoch 6, Step 40, Loss 0.0141
# (launch_and_fit pid=6191) Epoch 6, Step 50, Loss 0.0154
# (launch_and_fit pid=6191) Epoch 6, Step 60, Loss 0.0145
# (launch_and_fit pid=6191) Epoch 6, Step 70, Loss 0.2554
# (launch_and_fit pid=6191) Epoch 6, Step 80, Loss 0.0047
# (launch_and_fit pid=6191) Epoch 6, Step 90, Loss 0.0175
# (launch_and_fit pid=6191) Epoch 6, Step 100, Loss 0.0398
# (launch_and_fit pid=6191) Epoch 6, Step 110, Loss 0.0026
# (launch_and_fit pid=6191) Epoch 6, Step 120, Loss 0.0087
# (launch_and_fit pid=6191) Epoch 6, Step 130, Loss 0.0188
# (launch_and_fit pid=6191) Epoch 6, Step 140, Loss 0.0050
# (launch_and_fit pid=6191) Epoch 6, Valid Accuracy 92.86%
# (launch_and_fit pid=6191) [INFO] Patience 4 remaining
# (launch_and_fit pid=6191) Epoch 7, Step 0, Loss 0.2550
# (launch_and_fit pid=6191) Epoch 7, Step 10, Loss 0.0379
# (launch_and_fit pid=6191) Epoch 7, Step 20, Loss 0.0083
# (launch_and_fit pid=6191) Epoch 7, Step 30, Loss 0.0336
# (launch_and_fit pid=6191) Epoch 7, Step 40, Loss 0.0272
# (launch_and_fit pid=6191) Epoch 7, Step 50, Loss 0.0039
# (launch_and_fit pid=6191) Epoch 7, Step 60, Loss 0.0023
# (launch_and_fit pid=6191) Epoch 7, Step 70, Loss 0.0082
# (launch_and_fit pid=6191) Epoch 7, Step 80, Loss 0.0005
# (launch_and_fit pid=6191) Epoch 7, Step 90, Loss 0.0003
# (launch_and_fit pid=6191) Epoch 7, Step 100, Loss 0.0002
# (launch_and_fit pid=6191) Epoch 7, Step 110, Loss 0.0100
# (launch_and_fit pid=6191) Epoch 7, Step 120, Loss 0.0009
# (launch_and_fit pid=6191) Epoch 7, Step 130, Loss 0.0205
# (launch_and_fit pid=6191) Epoch 7, Step 140, Loss 0.0006
# (launch_and_fit pid=6191) Epoch 7, Valid Accuracy 94.44%
# (launch_and_fit pid=6191) [INFO] Patience 3 remaining
# (launch_and_fit pid=6191) Epoch 8, Step 0, Loss 0.0034
# (launch_and_fit pid=6191) Epoch 8, Step 10, Loss 0.0008
# (launch_and_fit pid=6191) Epoch 8, Step 20, Loss 0.0030
# (launch_and_fit pid=6191) Epoch 8, Step 30, Loss 0.0010
# (launch_and_fit pid=6191) Epoch 8, Step 40, Loss 0.0021
# (launch_and_fit pid=6191) Epoch 8, Step 50, Loss 0.0043
# (launch_and_fit pid=6191) Epoch 8, Step 60, Loss 0.0034
# (launch_and_fit pid=6191) Epoch 8, Step 70, Loss 0.0050
# (launch_and_fit pid=6191) Epoch 8, Step 80, Loss 0.0141
# (launch_and_fit pid=6191) Epoch 8, Step 90, Loss 0.0027
# (launch_and_fit pid=6191) Epoch 8, Step 100, Loss 0.1333
# (launch_and_fit pid=6191) Epoch 8, Step 110, Loss 0.2591
# (launch_and_fit pid=6191) Epoch 8, Step 120, Loss 0.1759
# (launch_and_fit pid=6191) Epoch 8, Step 130, Loss 0.0042
# (launch_and_fit pid=6191) Epoch 8, Step 140, Loss 0.0003
# (launch_and_fit pid=6191) Epoch 00009: reducing learning rate of group 0 to 1.0000e-04.
# (launch_and_fit pid=6191) Epoch 8, Valid Accuracy 95.24%
# (launch_and_fit pid=6191) [INFO] Patience 2 remaining
# (launch_and_fit pid=6191) Epoch 9, Step 0, Loss 0.0399
# (launch_and_fit pid=6191) Epoch 9, Step 10, Loss 0.0035
# (launch_and_fit pid=6191) Epoch 9, Step 20, Loss 0.3368
# (launch_and_fit pid=6191) Epoch 9, Step 30, Loss 3.7758
# (launch_and_fit pid=6191) Epoch 9, Step 40, Loss 0.0043
# (launch_and_fit pid=6191) Epoch 9, Step 50, Loss 0.0036
# (launch_and_fit pid=6191) Epoch 9, Step 60, Loss 0.0024
# (launch_and_fit pid=6191) Epoch 9, Step 70, Loss 0.0024
# (launch_and_fit pid=6191) Epoch 9, Step 80, Loss 0.0117
# (launch_and_fit pid=6191) Epoch 9, Step 90, Loss 0.0862
# (launch_and_fit pid=6191) Epoch 9, Step 100, Loss 0.2108
# (launch_and_fit pid=6191) Epoch 9, Step 110, Loss 0.0020
# (launch_and_fit pid=6191) Epoch 9, Step 120, Loss 0.0002
# (launch_and_fit pid=6191) Epoch 9, Step 130, Loss 0.0278
# (launch_and_fit pid=6191) Epoch 9, Step 140, Loss 0.0160
# (launch_and_fit pid=6191) Epoch 9, Valid Accuracy 92.86%
# (launch_and_fit pid=6191) [INFO] Patience 1 remaining
# (launch_and_fit pid=6191) Epoch 10, Step 0, Loss 0.0105
# (launch_and_fit pid=6191) Epoch 10, Step 10, Loss 0.0001
# (launch_and_fit pid=6191) Epoch 10, Step 20, Loss 0.0260
# (launch_and_fit pid=6191) Epoch 10, Step 30, Loss 0.0122
# (launch_and_fit pid=6191) Epoch 10, Step 40, Loss 0.0002
# (launch_and_fit pid=6191) Epoch 10, Step 50, Loss 0.0035
# (launch_and_fit pid=6191) Epoch 10, Step 60, Loss 0.0511
# (launch_and_fit pid=6191) Epoch 10, Step 70, Loss 0.0039
# (launch_and_fit pid=6191) Epoch 10, Step 80, Loss 0.0017
# (launch_and_fit pid=6191) Epoch 10, Step 90, Loss 0.0001
# (launch_and_fit pid=6191) Epoch 10, Step 100, Loss 0.0076
# (launch_and_fit pid=6191) Epoch 10, Step 110, Loss 0.0003
# (launch_and_fit pid=6191) Epoch 10, Step 120, Loss 0.0024
# (launch_and_fit pid=6191) Epoch 10, Step 130, Loss 0.0091
# (launch_and_fit pid=6191) Epoch 10, Step 140, Loss 0.0009
# (launch_and_fit pid=6191) Epoch 10, Valid Accuracy 94.44%
# (launch_and_fit pid=6191) [Early Stopping] Epoch 10, Valid Accuracy 94.44%, Valid Loss 0.1408
# (launch_and_fit pid=6191) [Client 0] get_parameters
# (launch_and_fit pid=6465) /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# (launch_and_fit pid=6465)   warnings.warn(
# (launch_and_fit pid=6465) [Client 1] fit, config: {}
# (launch_and_fit pid=6465) Epoch 0, Step 0, Loss 0.0313
# (launch_and_fit pid=6465) Epoch 0, Step 10, Loss 0.8378
# (launch_and_fit pid=6465) Epoch 0, Step 20, Loss 0.0038
# (launch_and_fit pid=6465) Epoch 0, Step 30, Loss 0.0015
# (launch_and_fit pid=6465) Epoch 0, Step 40, Loss 0.6026
# (launch_and_fit pid=6465) Epoch 0, Step 50, Loss 0.0009
# (launch_and_fit pid=6465) Epoch 0, Step 60, Loss 0.0063
# (launch_and_fit pid=6465) Epoch 0, Step 70, Loss 0.0012
# (launch_and_fit pid=6465) Epoch 0, Step 80, Loss 0.5053
# (launch_and_fit pid=6465) Epoch 0, Step 90, Loss 0.0126
# (launch_and_fit pid=6465) Epoch 0, Step 100, Loss 0.0000
# (launch_and_fit pid=6465) Epoch 0, Step 110, Loss 0.0010
# (launch_and_fit pid=6465) Epoch 0, Step 120, Loss 1.9705
# (launch_and_fit pid=6465) Epoch 0, Step 130, Loss 0.0000
# (launch_and_fit pid=6465) Epoch 0, Step 140, Loss 0.0058
# (launch_and_fit pid=6465) Epoch 0, Valid Accuracy 88.10%
# (launch_and_fit pid=6465) Epoch 1, Step 0, Loss 0.0005
# (launch_and_fit pid=6465) Epoch 1, Step 10, Loss 0.9790
# (launch_and_fit pid=6465) Epoch 1, Step 20, Loss 0.0011
# (launch_and_fit pid=6465) Epoch 1, Step 30, Loss 0.0498
# (launch_and_fit pid=6465) Epoch 1, Step 40, Loss 0.0037
# (launch_and_fit pid=6465) Epoch 1, Step 50, Loss 0.3417
# (launch_and_fit pid=6465) Epoch 1, Step 60, Loss 0.2549
# (launch_and_fit pid=6465) Epoch 1, Step 70, Loss 0.1260
# (launch_and_fit pid=6465) Epoch 1, Step 80, Loss 0.0010
# (launch_and_fit pid=6465) Epoch 1, Step 90, Loss 0.0005
# (launch_and_fit pid=6465) Epoch 1, Step 100, Loss 0.0007
# (launch_and_fit pid=6465) Epoch 1, Step 110, Loss 0.0069
# (launch_and_fit pid=6465) Epoch 1, Step 120, Loss 0.0001
# (launch_and_fit pid=6465) Epoch 1, Step 130, Loss 0.0332
# (launch_and_fit pid=6465) Epoch 1, Step 140, Loss 0.0035
# (launch_and_fit pid=6465) Epoch 1, Valid Accuracy 88.89%
# (launch_and_fit pid=6465) Epoch 2, Step 0, Loss 0.0001
# (launch_and_fit pid=6465) Epoch 2, Step 10, Loss 0.0114
# (launch_and_fit pid=6465) Epoch 2, Step 20, Loss 0.0004
# (launch_and_fit pid=6465) Epoch 2, Step 30, Loss 0.2912
# (launch_and_fit pid=6465) Epoch 2, Step 40, Loss 0.0005
# (launch_and_fit pid=6465) Epoch 2, Step 50, Loss 0.0027
# (launch_and_fit pid=6465) Epoch 2, Step 60, Loss 0.0026
# (launch_and_fit pid=6465) Epoch 2, Step 70, Loss 0.0526
# (launch_and_fit pid=6465) Epoch 2, Step 80, Loss 0.0000
# (launch_and_fit pid=6465) Epoch 2, Step 90, Loss 0.4714
# (launch_and_fit pid=6465) Epoch 2, Step 100, Loss 0.0187
# (launch_and_fit pid=6465) Epoch 2, Step 110, Loss 0.0006
# (launch_and_fit pid=6465) Epoch 2, Step 120, Loss 0.0192
# (launch_and_fit pid=6465) Epoch 2, Step 130, Loss 0.0032
# (launch_and_fit pid=6465) Epoch 2, Step 140, Loss 0.0551
# (launch_and_fit pid=6465) Epoch 2, Valid Accuracy 93.65%
# (launch_and_fit pid=6465) Epoch 3, Step 0, Loss 0.4115
# (launch_and_fit pid=6465) Epoch 3, Step 10, Loss 1.1409
# (launch_and_fit pid=6465) Epoch 3, Step 20, Loss 0.0135
# (launch_and_fit pid=6465) Epoch 3, Step 30, Loss 0.2539
# (launch_and_fit pid=6465) Epoch 3, Step 40, Loss 0.0001
# (launch_and_fit pid=6465) Epoch 3, Step 50, Loss 0.0021
# (launch_and_fit pid=6465) Epoch 3, Step 60, Loss 0.0090
# (launch_and_fit pid=6465) Epoch 3, Step 70, Loss 0.0102
# (launch_and_fit pid=6465) Epoch 3, Step 80, Loss 0.0281
# (launch_and_fit pid=6465) Epoch 3, Step 90, Loss 0.0103
# (launch_and_fit pid=6465) Epoch 3, Step 100, Loss 0.0022
# (launch_and_fit pid=6465) Epoch 3, Step 110, Loss 0.0331
# (launch_and_fit pid=6465) Epoch 3, Step 120, Loss 0.0234
# (launch_and_fit pid=6465) Epoch 3, Step 130, Loss 0.0045
# (launch_and_fit pid=6465) Epoch 3, Step 140, Loss 0.1467
# (launch_and_fit pid=6465) Epoch 3, Valid Accuracy 89.68%
# (launch_and_fit pid=6465) [INFO] Patience 5 remaining
# (launch_and_fit pid=6465) Epoch 4, Step 0, Loss 0.0101
# (launch_and_fit pid=6465) Epoch 4, Step 10, Loss 0.0013
# (launch_and_fit pid=6465) Epoch 4, Step 20, Loss 0.0016
# (launch_and_fit pid=6465) Epoch 4, Step 30, Loss 0.0012
# (launch_and_fit pid=6465) Epoch 4, Step 40, Loss 0.0000
# (launch_and_fit pid=6465) Epoch 4, Step 50, Loss 0.0185
# (launch_and_fit pid=6465) Epoch 4, Step 60, Loss 0.0002
# (launch_and_fit pid=6465) Epoch 4, Step 70, Loss 0.0102
# (launch_and_fit pid=6465) Epoch 4, Step 80, Loss 1.7026
# (launch_and_fit pid=6465) Epoch 4, Step 90, Loss 0.0049
# (launch_and_fit pid=6465) Epoch 4, Step 100, Loss 0.0143
# (launch_and_fit pid=6465) Epoch 4, Step 110, Loss 0.0107
# (launch_and_fit pid=6465) Epoch 4, Step 120, Loss 0.0043
# (launch_and_fit pid=6465) Epoch 4, Step 130, Loss 0.0139
# (launch_and_fit pid=6465) Epoch 4, Step 140, Loss 0.5296
# (launch_and_fit pid=6465) Epoch 4, Valid Accuracy 90.48%
# (launch_and_fit pid=6465) [INFO] Patience 4 remaining
# (launch_and_fit pid=6465) Epoch 5, Step 0, Loss 0.0113
# (launch_and_fit pid=6465) Epoch 5, Step 10, Loss 0.5008
# (launch_and_fit pid=6465) Epoch 5, Step 20, Loss 0.0020
# (launch_and_fit pid=6465) Epoch 5, Step 30, Loss 0.0049
# (launch_and_fit pid=6465) Epoch 5, Step 40, Loss 0.0048
# (launch_and_fit pid=6465) Epoch 5, Step 50, Loss 0.0035
# (launch_and_fit pid=6465) Epoch 5, Step 60, Loss 0.0536
# (launch_and_fit pid=6465) Epoch 5, Step 70, Loss 0.0554
# (launch_and_fit pid=6465) Epoch 5, Step 80, Loss 0.0031
# (launch_and_fit pid=6465) Epoch 5, Step 90, Loss 0.0347
# (launch_and_fit pid=6465) Epoch 5, Step 100, Loss 0.0054
# (launch_and_fit pid=6465) Epoch 5, Step 110, Loss 0.0021
# (launch_and_fit pid=6465) Epoch 5, Step 120, Loss 0.0099
# (launch_and_fit pid=6465) Epoch 5, Step 130, Loss 0.0156
# (launch_and_fit pid=6465) Epoch 5, Step 140, Loss 0.0018
# (launch_and_fit pid=6465) Epoch 5, Valid Accuracy 90.48%
# (launch_and_fit pid=6465) [INFO] Patience 3 remaining
# (launch_and_fit pid=6465) Epoch 6, Step 0, Loss 0.0086
# (launch_and_fit pid=6465) Epoch 6, Step 10, Loss 0.0078
# (launch_and_fit pid=6465) Epoch 6, Step 20, Loss 0.0016
# (launch_and_fit pid=6465) Epoch 6, Step 30, Loss 0.0006
# (launch_and_fit pid=6465) Epoch 6, Step 40, Loss 0.0004
# (launch_and_fit pid=6465) Epoch 6, Step 50, Loss 0.0002
# (launch_and_fit pid=6465) Epoch 6, Step 60, Loss 0.0079
# (launch_and_fit pid=6465) Epoch 6, Step 70, Loss 0.0002
# (launch_and_fit pid=6465) Epoch 6, Step 80, Loss 0.0012
# (launch_and_fit pid=6465) Epoch 6, Step 90, Loss 0.0122
# (launch_and_fit pid=6465) Epoch 6, Step 100, Loss 0.0216
# (launch_and_fit pid=6465) Epoch 6, Step 110, Loss 0.0192
# (launch_and_fit pid=6465) Epoch 6, Step 120, Loss 0.0045
# (launch_and_fit pid=6465) Epoch 6, Step 130, Loss 0.0522
# (launch_and_fit pid=6465) Epoch 6, Step 140, Loss 0.0450
# (launch_and_fit pid=6465) Epoch 00007: reducing learning rate of group 0 to 1.0000e-04.
# (launch_and_fit pid=6465) Epoch 6, Valid Accuracy 89.68%
# (launch_and_fit pid=6465) [INFO] Patience 2 remaining
# (launch_and_fit pid=6465) Epoch 7, Step 0, Loss 0.0001
# (launch_and_fit pid=6465) Epoch 7, Step 10, Loss 0.0001
# (launch_and_fit pid=6465) Epoch 7, Step 20, Loss 0.0156
# (launch_and_fit pid=6465) Epoch 7, Step 30, Loss 0.0429
# (launch_and_fit pid=6465) Epoch 7, Step 40, Loss 0.0146
# (launch_and_fit pid=6465) Epoch 7, Step 50, Loss 0.9077
# (launch_and_fit pid=6465) Epoch 7, Step 60, Loss 0.0077
# (launch_and_fit pid=6465) Epoch 7, Step 70, Loss 0.0009
# (launch_and_fit pid=6465) Epoch 7, Step 80, Loss 0.0036
# (launch_and_fit pid=6465) Epoch 7, Step 90, Loss 0.0006
# (launch_and_fit pid=6465) Epoch 7, Step 100, Loss 0.1007
# (launch_and_fit pid=6465) Epoch 7, Step 110, Loss 0.0002
# (launch_and_fit pid=6465) Epoch 7, Step 120, Loss 0.0307
# (launch_and_fit pid=6465) Epoch 7, Step 130, Loss 0.0020
# (launch_and_fit pid=6465) Epoch 7, Step 140, Loss 0.0316
# (launch_and_fit pid=6465) Epoch 7, Valid Accuracy 93.65%
# (launch_and_fit pid=6465) [INFO] Patience 1 remaining
# (launch_and_fit pid=6465) Epoch 8, Step 0, Loss 0.0018
# (launch_and_fit pid=6465) Epoch 8, Step 10, Loss 0.0755
# (launch_and_fit pid=6465) Epoch 8, Step 20, Loss 0.0028
# (launch_and_fit pid=6465) Epoch 8, Step 30, Loss 0.0000
# (launch_and_fit pid=6465) Epoch 8, Step 40, Loss 0.0004
# (launch_and_fit pid=6465) Epoch 8, Step 50, Loss 0.3402
# (launch_and_fit pid=6465) Epoch 8, Step 60, Loss 0.0018
# (launch_and_fit pid=6465) Epoch 8, Step 70, Loss 0.0009
# (launch_and_fit pid=6465) Epoch 8, Step 80, Loss 0.0004
# (launch_and_fit pid=6465) Epoch 8, Step 90, Loss 1.0013
# (launch_and_fit pid=6465) Epoch 8, Step 100, Loss 0.0007
# (launch_and_fit pid=6465) Epoch 8, Step 110, Loss 0.0012
# (launch_and_fit pid=6465) Epoch 8, Step 120, Loss 0.0003
# (launch_and_fit pid=6465) Epoch 8, Step 130, Loss 0.0006
# (launch_and_fit pid=6465) Epoch 8, Step 140, Loss 0.0003
# (launch_and_fit pid=6465) Epoch 8, Valid Accuracy 89.68%
# (launch_and_fit pid=6465) [Early Stopping] Epoch 8, Valid Accuracy 89.68%, Valid Loss 0.4472
# (launch_and_fit pid=6465) [Client 1] get_parameters
# DEBUG flower 2023-12-12 02:12:57,996 | server.py:277 | fit_round received 2 results and 0 failures
# INFO flower 2023-12-12 02:13:10,133 | server.py:158 | fit progress: (10, 0.017048672750769628, {'val_accuracy': 0.9523809523809523, 'test_accuracy': 0.95260663507109}, 7481.163818605999)
# INFO flower 2023-12-12 02:13:10,134 | server.py:209 | evaluate_round: no clients selected, cancel
# INFO flower 2023-12-12 02:13:10,135 | server.py:182 | FL finished in 7481.165993340999
# INFO flower 2023-12-12 02:13:10,141 | app.py:149 | app_fit: losses_distributed []
# INFO flower 2023-12-12 02:13:10,142 | app.py:150 | app_fit: metrics_distributed {}
# INFO flower 2023-12-12 02:13:10,143 | app.py:151 | app_fit: losses_centralized [(0, 0.17667243310383388), (1, 0.1584599633065481), (2, 0.030619340970934855), (3, 0.02348912709451739), (4, 0.023028130480457865), (5, 0.024998806292719635), (6, 0.03059075171467922), (7, 0.02114759900631191), (8, 0.02986213556926934), (9, 0.021277943278648077), (10, 0.017048672750769628)]
# INFO flower 2023-12-12 02:13:10,144 | app.py:152 | app_fit: metrics_centralized {'val_accuracy': [(0, 0.36507936507936506), (1, 0.5317460317460317), (2, 0.9206349206349206), (3, 0.9365079365079365), (4, 0.9365079365079365), (5, 0.9523809523809523), (6, 0.9365079365079365), (7, 0.9523809523809523), (8, 0.9365079365079365), (9, 0.9285714285714286), (10, 0.9523809523809523)], 'test_accuracy': [(0, 0.36729857819905215), (1, 0.566350710900474), (2, 0.9383886255924171), (3, 0.9478672985781991), (4, 0.9454976303317536), (5, 0.9549763033175356), (6, 0.9383886255924171), (7, 0.9549763033175356), (8, 0.9454976303317536), (9, 0.957345971563981), (10, 0.95260663507109)]}

# %% [markdown]
# ## Plotting Grpahs

# %%
import matplotlib.pyplot as plt

rounds = [x for x in range(len(res.metrics_centralized['val_accuracy']))]
val_accuracies = [x[1] for x in res.metrics_centralized['val_accuracy']]
test_accuracies = [x[1] for x in res.metrics_centralized['test_accuracy']]

# Plotting
plt.figure(figsize=(8, 6))
# plt.ylim([-1,2])
plt.plot(rounds, val_accuracies, 'b',marker="o", label='Validation Accuracy')
plt.plot(rounds, test_accuracies, 'r',marker="o", label='Test Accuracy')
# plt.plot(epochs, val_losses, 'r', label='Validation Loss')
plt.title('Validation and Test Accuracy')
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

rounds = range(0, len(res.losses_centralized))
val_losses = [x[1] for x in res.losses_centralized]

# Plotting
plt.figure(figsize=(8, 6))
# plt.ylim([-1,2])
plt.plot(rounds, val_losses, 'b', marker="o", label='Validation Loss')
# plt.plot(epochs, val_losses, 'r', label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Rounds')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
res
# Out:
# History (loss, centralized):
# 	round 0: 0.17667243310383388
# 	round 1: 0.1584599633065481
# 	round 2: 0.030619340970934855
# 	round 3: 0.02348912709451739
# 	round 4: 0.023028130480457865
# 	round 5: 0.024998806292719635
# 	round 6: 0.03059075171467922
# 	round 7: 0.02114759900631191
# 	round 8: 0.02986213556926934
# 	round 9: 0.021277943278648077
# 	round 10: 0.017048672750769628
# History (metrics, centralized):
# {'val_accuracy': [(0, 0.36507936507936506), (1, 0.5317460317460317), (2, 0.9206349206349206), (3, 0.9365079365079365), (4, 0.9365079365079365), (5, 0.9523809523809523), (6, 0.9365079365079365), (7, 0.9523809523809523), (8, 0.9365079365079365), (9, 0.9285714285714286), (10, 0.9523809523809523)], 'test_accuracy': [(0, 0.36729857819905215), (1, 0.566350710900474), (2, 0.9383886255924171), (3, 0.9478672985781991), (4, 0.9454976303317536), (5, 0.9549763033175356), (6, 0.9383886255924171), (7, 0.9549763033175356), (8, 0.9454976303317536), (9, 0.957345971563981), (10, 0.95260663507109)]}
